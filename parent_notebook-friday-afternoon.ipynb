# %% [markdown]
# # Unemployment rate in SA

# %% [markdown]
# ## How does different economic factors affect Unemployment rate ?
#
# The purpose of this notebook is to explore variables that could potetially have a relationship with our response variables, i.e unemployment rate.
# <br>
# <br>
# We will first start of by exploring which varibles have a relationship with the unemployment rate then after use those variables to answer the following questions:
# <br>
# <br>
# **Questions:**<br>
# 1. How does the government cash flow affect unemployment rate?
# 2. Do investment returns affect the employment rate?
# 3. How does the government assets affect unemployment rate?
# 4. How does the government debt affect unemployment rate?
# <br>
# <br>
# We will explore this relationship using the regression slope test that has a regression line of the format:
# <br>
# $$
# Y=\beta_{i} X \ for \ i = 0,1,2...m
# $$
# Where $X$ are the selected variables and $\beta_{i}$ are the respective coefficients.Thus, the **hypothesis** is as follows:
# $$
# \begin{array}{l}{\mathrm{H}_{\mathrm{0}} : \beta_{0}=\beta_{1}=...=\beta_{m}=0} \\ {\mathrm{H}_{\mathrm{1}} : \beta_{i} \neq 0 } \ for \ at \ least\ one \ i\end{array}
# $$
#
# <br>
# <br>
# We will be using the $F$-test to simultaneously check the significance of a number of regression coefficients.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import RFE
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')
from scipy import stats
from sklearn.metrics import r2_score
from sklearn import preprocessing
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats
from statsmodels.formula.api import rlm
import statsmodels.api as sm
from sklearn.utils import resample
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import mean_squared_error
import re
import string

# %% [markdown]
# # Data Collection

# %% [markdown]
# ### South African Reserve Bank Cleaned Economic Data
#
# Data prepared for modelling from the South African Reserve Bank
#
# This data can used for both regression and classification research questions i.e. forecast the unemployment rate.
#
# The original data was sourced from https://www.resbank.co.za/en/home/what-we-do/statistics/releases/economic-and-financial-data-for-south-africa
#
#
# ### The full feature set
# *These feature were accessed from the South African Reserve Bank.*
#
# *There are **147 features in total**, these cover a significant portfion of the South African economy*
#
# **The data from 1922-01-01 to 2020-01-01** if it used for unemployment forecasting, deleting redudant observations is helpful

# %%
feature_set_sarb = pd.read_csv('sarb_features_data.csv').set_index('Date')
target = pd.read_csv('sarb_target_data.csv').set_index('Date')

# %% [markdown]
# # Data Preparation
#
# ## Missing Data
#
# The missing data occurs because we are merging data that is monthly and data that is quartely, hence all quartely data should be expected to have missing data. This is normal when dealing with multiple time series.

# %%
#Here we visualize the frequency of missingness of each feature
feature = feature_set_sarb.isna().sum()/len(feature_set_sarb)

feature = feature.sort_values(ascending=False)
feature_df = pd.DataFrame(feature.index, columns=['Feature Name'])
feature_df['Missing Frequency'] = np.array(feature.values)
feature_df['Rank'] = feature_df['Missing Frequency'].rank(ascending=False)
#feature_df
feature_df
# Out:
#                                           Feature Name  Missing Frequency  \
# 0                                             Loans _y           0.986732
# 1    Consolidated general government: Liabilities: ...           0.959497
# 2    The difference between cash-flow revenue and c...           0.958799
# 3                       Total South African population           0.958101
# 4            Foreign debt of S.A.: Total foreign debt            0.953212
# 5                                               Loans            0.951117
# 6                     Other domestic financial assets            0.951117
# 7                                             Foreign            0.951117
# 8                                            Domestic            0.951117
# 9                        Capital account: credit (nsa)           0.947626
# 10                      Current transfers: debit (nsa)           0.947626
# 11                     Current transfers: credit (nsa)           0.947626
# 12                        Capital account: debit (nsa)           0.947626
# 13                            Imports of goods (SARS)            0.933659
# 14            Exports of goods, including gold (SARS)            0.933659
# 15                               IMF reserve position            0.932263
# 16                                Other reserve assets           0.932263
# 17   Consolidated general government: Liabilities: ...           0.920391
# 18                                            Loans _x           0.920391
# 19   Consolidated general government: Liabilities: ...           0.920391
# 20        Consolidated general government: Liabilities           0.920391
# 21   Consolidated general government: Liabilities: ...           0.920391
# 22   Consolidated general government: Liabilities: ...           0.920391
# 23   Consolidated general government: Liabilities: ...           0.920391
# 24   Consolidated general government: Net change in...           0.920391
# 25   Consolidated general government: Cash surplus ...           0.920391
# 26            Consolidated general government: Expense           0.920391
# 27   Consolidated general government: Liabilities: ...           0.920391
# 28   Consolidated general government: Net cash-flow...           0.920391
# 29   Consolidated general government: Net change in...           0.920391
# ..                                                 ...                ...
# 118  The leading business cycle indicator is a comp...           0.497905
# 119  The difference between cash-flow revenue and c...           0.497207
# 120   Total outstanding domestic non-marketable bills            0.497207
# 121  Total outstanding foreign marketable bonds by ...           0.497207
# 122                    Total domestic marketable bonds           0.497207
# 123  Total outstanding foreign marketable bonds by ...           0.497207
# 124      Net foreign assets after valuation adjustment           0.497207
# 125        Total outstanding domestic marketable bills           0.497207
# 126  National government expenditure adjusted for d...           0.497207
# 127                  Financing by non-marketable bonds           0.497207
# 128  Cash received from the issuance of foreign bon...           0.497207
# 129                                 Total foreign debt           0.497207
# 130  Gross gold and other foreign reserves : Amount...           0.497207
# 131  National government revenue adjusted for diffe...           0.497207
# 132                      Total foreign marketable debt           0.497207
# 133        Total outstanding domestic marketable debt            0.497207
# 134  Cash received from the issuance of Treasury bi...           0.497207
# 135  Including changes in the Exchequer and Paymast...           0.497207
# 136                 Total foreign non-marketable debt            0.497207
# 137  The net borrowing requirement of national gove...           0.497207
# 138                       Total gross loan debt (nsa)            0.497207
# 139  Total outstanding foreign marketable bonds by ...           0.497207
# 140       Cost/profit of revaluation of foreign loans            0.497207
# 141     Total outstanding domestic non-marketable debt           0.497207
# 142  Cash received from the issuance of other debt ...           0.497207
# 143    Total outstanding domestic non-marketable bonds           0.497207
# 144                            Total cash-flow revenue           0.497207
# 145  Total outstanding domestic non-marketable loan...           0.497207
# 146    Foreign exchange rate : SA rand per USA dollar            0.496508
# 147                                      CPI Headline            0.178771
#
#       Rank
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
# 5      7.5
# 6      7.5
# 7      7.5
# 8      7.5
# 9     11.5
# 10    11.5
# 11    11.5
# 12    11.5
# 13    14.5
# 14    14.5
# 15    16.5
# 16    16.5
# 17    25.5
# 18    25.5
# 19    25.5
# 20    25.5
# 21    25.5
# 22    25.5
# 23    25.5
# 24    25.5
# 25    25.5
# 26    25.5
# 27    25.5
# 28    25.5
# 29    25.5
# ..     ...
# 118  119.0
# 119  133.0
# 120  133.0
# 121  133.0
# 122  133.0
# 123  133.0
# 124  133.0
# 125  133.0
# 126  133.0
# 127  133.0
# 128  133.0
# 129  133.0
# 130  133.0
# 131  133.0
# 132  133.0
# 133  133.0
# 134  133.0
# 135  133.0
# 136  133.0
# 137  133.0
# 138  133.0
# 139  133.0
# 140  133.0
# 141  133.0
# 142  133.0
# 143  133.0
# 144  133.0
# 145  133.0
# 146  147.0
# 147  148.0
#
# [148 rows x 3 columns]

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
plt.bar(feature_df['Feature Name'], feature_df['Missing Frequency'])
# Out:
# <BarContainer object of 148 artists>

# %% [markdown]
# ## Imputation

# %%
# Data imputation strategy is foward fill i.e last know value imputation
# Economic data usually does not change that much from month to month.
x_values_ffill = feature_set_sarb.fillna(method='ffill')
y_values_ffill = target.fillna(method='ffill')

# %%
# Remove all data points before unemployment rate data is available. Unemployment rate is my target variable.
valid_start = y_values_ffill.first_valid_index()
y_values_ffill = y_values_ffill[valid_start : ]
x_values_ffill = x_values_ffill[valid_start : ]

# %%
#We fill with NA here to avoid any features that might be NA i.e. insurance
x_values_ffill = x_values_ffill.fillna(0)
x_values_ffill.isna().sum()
# Out:
# Final consumption expenditure by general government                                                                                                                                                                                                           0
# Consolidated general government: Revenue                                                                                                                                                                                                                      0
# Foreign liabilities: Total portfolio investment                                                                                                                                                                                                               0
# Foreign liabilities: Portfolio investment: Equity securities                                                                                                                                                                                                  0
# Domestic output: All groups                                                                                                                                                                                                                                   0
# Final consumption expenditure by households: Total                                                                                                                                                                                                            0
# Gross fixed capital formation                                                                                                                                                                                                                                 0
# SDDS - Financial derivative liabilities                                                                                                                                                                                                                       0
# Foreign liabilities: Portfolio investment: Debt securities                                                                                                                                                                                                    0
# Change in inventories                                                                                                                                                                                                                                         0
# Gross domestic product at market prices                                                                                                                                                                                                                       0
# Foreign debt of S.A.: Total foreign debt                                                                                                                                                                                                                      0
# Foreign exchange rate : SA rand per USA dollar                                                                                                                                                                                                                0
# Gross value added at basic prices of all industries                                                                                                                                                                                                           0
# Other domestic financial assets                                                                                                                                                                                                                               0
# Gross value added at basic prices of other community, social and personal services                                                                                                                                                                            0
# Net Investment Position                                                                                                                                                                                                                                       0
# Foreign liabilities: Total other investment                                                                                                                                                                                                                   0
# Gross value added at basic prices of general government services                                                                                                                                                                                              0
# Foreign                                                                                                                                                                                                                                                       0
# Total outstanding domestic non-marketable bills                                                                                                                                                                                                               0
# Financing by non-marketable bonds                                                                                                                                                                                                                             0
# Total gross loan debt (nsa)                                                                                                                                                                                                                                   0
# Reserve Bank SDR reserves                                                                                                                                                                                                                                     0
# SDDS - Reserve Assest                                                                                                                                                                                                                                         0
# Foreign assets: Total other investment                                                                                                                                                                                                                        0
# IMF reserve position                                                                                                                                                                                                                                          0
# Financial guarantees by government                                                                                                                                                                                                                            0
# Total cash-flow revenue                                                                                                                                                                                                                                       0
# Total outstanding domestic non-marketable bonds                                                                                                                                                                                                               0
#                                                                                                                                                                                                                                                              ..
# Claims on the domestic private sector                                                                                                                                                                                                                         0
# Total foreign non-marketable debt                                                                                                                                                                                                                             0
# Capital account (nsa)                                                                                                                                                                                                                                         0
# Portfolio investment, assets                                                                                                                                                                                                                                  0
# Direct investment in reporting economy                                                                                                                                                                                                                        0
# Current transfers: debit (nsa)                                                                                                                                                                                                                                0
# Total outstanding foreign marketable bonds by unexpired maturity: Exceeding 3 years                                                                                                                                                                           0
# Broad monetary credit to the government sector                                                                                                                                                                                                                0
# Consolidated general government: Liabilities: Foreign                                                                                                                                                                                                         0
# National government expenditure adjusted for differences between the recording of transactions and bank clearances, and late departmental requests/surrenders of funds.                                                                                       0
# Consolidated general government: Net cash-flow from financing activities                                                                                                                                                                                      0
# Exports of goods & services                                                                                                                                                                                                                                   0
# Total South African population                                                                                                                                                                                                                                0
# The nominal effective exchange rate is a weighted exchange rate of the rand measured against a basket of the currencies of South Africa's twenty most important trading partners. The calculation is based on trade in and consumption of manufactured goo    0
# Imports of goods & services                                                                                                                                                                                                                                   0
# Consolidated general government: Net acquisition of financial assets other than cash                                                                                                                                                                          0
# The leading business cycle indicator is a composite index comprising of time series, which tend to shift direction in advance of the business cycle. Frequency = monthly. Currency = index (2015 = 100). The time series is seasonally adjusted.              0
# Loans                                                                                                                                                                                                                                                         0
# Domestic                                                                                                                                                                                                                                                      0
# Physical volume of manufacturing production: Total                                                                                                                                                                                                            0
# Remuneration per worker in non-agricultural: Total                                                                                                                                                                                                            0
# Consolidated general government: Non-financial assets - Net                                                                                                                                                                                                   0
# Consolidated general government: Cash surplus / deficit                                                                                                                                                                                                       0
# CPI Headline                                                                                                                                                                                                                                                  0
# Gross domestic expenditure                                                                                                                                                                                                                                    0
# Net cash-flow from operating activities                                                                                                                                                                                                                       0
# Non-agricultural employment: Total                                                                                                                                                                                                                            0
# Consolidated general government: Expense                                                                                                                                                                                                                      0
# Residual item                                                                                                                                                                                                                                                 0
# unemployment rate                                                                                                                                                                                                                                             0
# Length: 148, dtype: int64

# %% [markdown]
# # Helper functions

# %%
def model_fit(X,y):    
    #no of features
    feature_list=np.arange(1, len(X.columns))            
    high_score=0
    #Variable to store the optimum features
    optimum_no_featurcashes=0           
    score_list =[]
    for n in range(len(feature_list)):
        model = LinearRegression()
        rfe = RFE(model,feature_list[n])
        X_train_rfe = rfe.fit_transform(X,y)
        model.fit(X_train_rfe,y)
        # R2 score for measurement
        score = r2_score(y, model.predict(X_train_rfe))
        score_list.append(score)
        
        if n % 10 == 0:
            print(n,score)
            
        if(score>high_score):
            high_score = score  
            optimum_no_features = feature_list[n]
    return score_list, optimum_no_features

# %%
def plt_plot(values,title, x_label, y_label):
    
    plt.plot(values)
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)

# %%
def final_model(optimum_no_features, X_train, y_train,cols):
    model = LinearRegression()
    #Initializing RFE model
    rfe = RFE(model, optimum_no_features)             
    #Transforming data using RFE
    x_fitted = rfe.fit_transform(X_train,y_train)  
    #Fitting the data to model
    model.fit(x_fitted,y_train)              
    temp = pd.Series(rfe.support_,index = cols)
    selected_features = temp[temp==True].index
    return selected_features, model, rfe

# %%
def print_p_values(x_test, y_test, predicted, params):
    """
    Calculates the p value, based on https://stackoverflow.com/a/42677750/9260653
    """
    newX = np.append(np.ones((len(x_test),1)), x_test, axis=1)
    MSE = (sum((y_test.values-predicted)**2))/(len(newX)-len(newX[0]))

    var_b = MSE*(np.linalg.pinv(np.dot(newX.T,newX)).diagonal())
    sd_b = np.sqrt(var_b)[:-1]
    ts_b = params/ sd_b

    p_values =[2*(1-stats.t.cdf(np.abs(i),(len(newX)-1))) for i in ts_b]

    sd_b = np.round(sd_b,3)
    ts_b = np.round(ts_b,3)
    p_values = np.round(p_values,3)
    params = np.round(params,4)

    myDF3 = pd.DataFrame()
    myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["P-Values"] = [params,sd_b,ts_b,p_values]
    print(myDF3.iloc[1])

# %% [markdown]
# # Unemployment rate in SA :

# %% [markdown]
# ##  1. How does the government assets affect unemployment rate?

# %% [markdown]
# ## Features relating to assets

# %% [markdown]
# ### Get features associated with assests

# %%
df_out = list()
for i in x_values_ffill:
    if 'assets' in i:
        df_out.append(i)
df_out.append("unemployment rate")
df_out #7
# Out:
# ['Other domestic financial assets ',
#  'Foreign assets: Total other investment',
#  'Foreign assets: Portfolio investment: Debt securities',
#  'Foreign assets: Total direct investment',
#  'Reserve assets',
#  'Total foreign assets',
#  'Other reserve assets',
#  'Foreign assets: Total portfolio investment',
#  'Foreign assets: Portfolio investment: Equity securities',
#  'Other investment, assets',
#  'Financial derivatives, assets',
#  'Total foreign assets minus total foreign liabilities',
#  'Net foreign assets after valuation adjustment',
#  'Portfolio investment, assets',
#  'Consolidated general government: Net acquisition of financial assets other than cash',
#  'Consolidated general government: Non-financial assets - Net',
#  'unemployment rate']

# %%
df_assets2 = x_values_ffill[df_out]
df_assets2.rename(columns={'Portfolio investment, assets':'PortfolioInvestmentAssets',
        'Foreign assets: Portfolio investment: Debt securities': 'ForeignAssetsPortfolioInvestmentDebtSecurities',
                        'Consolidated general government: Non-financial assets - Net':'ConsolidatedGeneralGovernmentNonfinancialAssetsNet',
                          'Foreign assets: Total other investment': 'ForeignAssetsTotalOtherInvestment',
                          'Foreign assets: Total direct investment': 'ForeignAssetsTotalDirectInvestment',
                          'Other investment, assets':'OtherInvestmentAssets',
                          'Financial derivatives, assets':'FinancialDerivativesAssets',
                           'Foreign assets: Portfolio investment: Equity securities': 'ForeignAssetsPortfolioInvestmentEquitySecurities',
                          'Other domestic financial assets ':'OtherDomesticFinancialAssets',
                          'Total foreign assets':'TotalForeignAssets',
                          'Total foreign assets minus total foreign liabilities':'TotalForeignAssetsMinusTotalForeignLiabilities',
                          'Net foreign assets after valuation adjustment':'NetForeignAssetsAfterValuationAdjustment',
                          'Foreign assets: Total portfolio investment':'ForeignAssetsTotalPortfolioInvestment',
                          'Reserve assets':'ReserveAssets'}
                  , inplace=True)
del df_assets2["Other reserve assets"]
corr_df = df_assets2.corr(method='pearson')

fig, ax = plt.subplots(figsize=(15,10))


mask=np.zeros_like(corr_df)
mask[np.triu_indices_from(mask)]=True
sns.heatmap(corr_df,cmap='RdYlGn_r',vmax=1.0,vmin=-1.0,mask=mask,linewidths=2.5,ax=ax)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# It appears most of the assets are positively correlated with unemployment rate, however, there is also strong correlation between some assets which may lead to problem of colinearity

# %% [markdown]
# #### Here I am separating features from the target variable

# %%
X= df_assets2
del X["unemployment rate"]
df2 = y_values_ffill.rename(columns={'unemployment rate':'unemployment_rate'})

y = df2['unemployment_rate']

# %% [markdown]
# Earlier on, we saw that some of our fetaures we strongly correlated that could cause issue of multicollinearity, to resolve that, I shall optimize my feature space by removing features with correlation more than 0.8 .

# %%
correlated_features = set()
correlation_matrix = X.corr()

for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)
# Out:
# 9

# %%
print(correlated_features)
# Out:
# {'TotalForeignAssetsMinusTotalForeignLiabilities', 'FinancialDerivativesAssets', 'Consolidated general government: Net acquisition of financial assets other than cash', 'TotalForeignAssets', 'ConsolidatedGeneralGovernmentNonfinancialAssetsNet', 'ForeignAssetsTotalPortfolioInvestment', 'ForeignAssetsPortfolioInvestmentEquitySecurities', 'ForeignAssetsPortfolioInvestmentDebtSecurities', 'ForeignAssetsTotalDirectInvestment'}

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)
X.shape
# Out:
# (794, 6)

# %% [markdown]
# Having obtained the optimized features, below we select them and in our new dataset and plot the correlation matrix.

# %%
corr_df = X.corr(method='pearson')

fig, ax = plt.subplots(figsize=(15,10))


mask=np.zeros_like(corr_df)
mask[np.triu_indices_from(mask)]=True
sns.heatmap(corr_df,cmap='RdYlGn_r',vmax=1.0,vmin=-1.0,mask=mask,linewidths=2.5,ax=ax)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Partitioning the Data into Training(70%) and Testing(30%) sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)

# %%
X_train
# Out:
#             OtherDomesticFinancialAssets  ForeignAssetsTotalOtherInvestment  \
# Date
# 1976-08-01                           0.0                                2.0
# 1991-01-12                           0.0                                7.0
# 1996-04-01                           0.0                               18.0
# 1976-01-06                           0.0                                0.0
# 2006-10-01                        8839.0                              247.0
# 1985-10-01                           0.0                                5.0
# 1989-11-01                           0.0                                8.0
# 2016-10-01                       46311.0                              521.0
# 1992-07-01                           0.0                                9.0
# 1994-11-01                           0.0                               11.0
# 2019-01-09                        -364.0                              598.0
# 2006-02-01                        8839.0                              247.0
# 1983-06-01                           0.0                                3.0
# 1995-10-01                           0.0                               12.0
# 1980-08-01                           0.0                                3.0
# 1985-01-12                           0.0                                5.0
# 1982-01-06                           0.0                                0.0
# 1992-09-01                           0.0                                9.0
# 1992-01-01                           0.0                                7.0
# 2004-12-01                       16504.0                              164.0
# 2017-10-01                      -11895.0                              530.0
# 1980-01-03                           0.0                                0.0
# 2016-02-01                       46311.0                              521.0
# 2013-01-12                       28897.0                              398.0
# 1994-01-12                           0.0                               11.0
# 1991-11-01                           0.0                                7.0
# 1974-05-01                           0.0                                1.0
# 1995-06-01                           0.0                               12.0
# 2008-04-01                        2921.0                              303.0
# 1980-04-01                           0.0                                3.0
# ...                                  ...                                ...
# 1997-02-01                           0.0                               24.0
# 2014-08-01                       23277.0                              463.0
# 2017-06-01                      -11895.0                              530.0
# 1977-06-01                           0.0                                2.0
# 1974-11-01                           0.0                                1.0
# 2003-12-01                       16134.0                              165.0
# 2012-08-01                       15110.0                              320.0
# 2019-01-03                      -74367.0                              619.0
# 1981-01-12                           0.0                                3.0
# 1975-10-01                           0.0                                1.0
# 2004-10-01                       16504.0                              164.0
# 2000-09-01                           0.0                               60.0
# 2014-04-01                       23277.0                              463.0
# 1990-01-01                           0.0                                8.0
# 1995-01-06                           0.0                                0.0
# 2007-11-01                       12539.0                              271.0
# 1999-11-01                           0.0                               47.0
# 1974-09-01                           0.0                                1.0
# 2007-10-01                       12539.0                              271.0
# 2017-05-01                      -11895.0                              530.0
# 1987-08-01                           0.0                                7.0
# 2015-06-01                        6572.0                              561.0
# 1970-12-01                           0.0                                1.0
# 1992-10-01                           0.0                                9.0
# 2014-06-01                       23277.0                              463.0
# 2018-01-03                      -18450.0                              528.0
# 1982-03-01                           0.0                                3.0
# 2009-08-01                      -14320.0                              251.0
# 2005-02-01                       17533.0                              196.0
# 2013-01-06                      -32247.0                                0.0
#
#             ReserveAssets  OtherInvestmentAssets  \
# Date
# 1976-08-01          0.000                    0.0
# 1991-01-12         88.000                  502.0
# 1996-04-01       -752.000                -3779.0
# 1976-01-06          0.000                    0.0
# 2006-10-01      -7721.000                 3952.0
# 1985-10-01       -185.000                  337.0
# 1989-11-01       -698.000                 -352.0
# 2016-10-01     -54301.000                -9229.0
# 1992-07-01       2345.000                 -917.0
# 1994-11-01      -2323.058                 -573.0
# 2019-01-09     -77164.000                82933.0
# 2006-02-01      -7721.000                 3952.0
# 1983-06-01          0.000                    0.0
# 1995-10-01      -5680.000                   84.0
# 1980-08-01          0.000                    0.0
# 1985-01-12       -185.000                  337.0
# 1982-01-06          0.000                    0.0
# 1992-09-01       2345.000                 -917.0
# 1992-01-01         88.000                  502.0
# 2004-12-01     -13988.000                 3671.0
# 2017-10-01     -14902.000                 -881.0
# 1980-01-03          0.000                    0.0
# 2016-02-01     -54301.000                -9229.0
# 2013-01-12         31.000                  844.0
# 1994-01-12      -2323.058                 -573.0
# 1991-11-01         88.000                  502.0
# 1974-05-01          0.000                    0.0
# 1995-06-01      -5680.000                   84.0
# 2008-04-01      -5830.000                64271.0
# 1980-04-01          0.000                    0.0
# ...                   ...                    ...
# 1997-02-01       2523.000                  304.0
# 2014-08-01      -7623.000               -14448.0
# 2017-06-01     -14902.000                 -881.0
# 1977-06-01          0.000                    0.0
# 1974-11-01          0.000                    0.0
# 2003-12-01       -209.000               -17762.0
# 2012-08-01       -349.000                11967.0
# 2019-01-03      34244.000               -51571.0
# 1981-01-12          0.000                    0.0
# 1975-10-01          0.000                    0.0
# 2004-10-01     -13988.000                 3671.0
# 2000-09-01         18.000                 2982.0
# 2014-04-01      -7623.000               -14448.0
# 1990-01-01       -698.000                 -352.0
# 1995-01-06      -1267.000                 1403.0
# 2007-11-01     -16084.000                30104.0
# 1999-11-01      -3136.000               -10254.0
# 1974-09-01          0.000                    0.0
# 2007-10-01     -16084.000                30104.0
# 2017-05-01     -14902.000                 -881.0
# 1987-08-01        -62.000                 -115.0
# 2015-06-01      -3454.000                47897.0
# 1970-12-01          0.000                    0.0
# 1992-10-01       2345.000                 -917.0
# 2014-06-01      -7623.000               -14448.0
# 2018-01-03      14571.000               -21611.0
# 1982-03-01          0.000                    0.0
# 2009-08-01      -2288.000                  846.0
# 2005-02-01      -6612.000                 9487.0
# 2013-01-06      15149.000                  968.0
#
#             NetForeignAssetsAfterValuationAdjustment  \
# Date
# 1976-08-01                                     -77.0
# 1991-01-12                                    1601.0
# 1996-04-01                                   -4505.0
# 1976-01-06                                    -243.0
# 2006-10-01                                  -17016.0
# 1985-10-01                                    -287.0
# 1989-11-01                                     859.0
# 2016-10-01                                   70897.0
# 1992-07-01                                     849.0
# 1994-11-01                                    1323.0
# 2019-01-09                                  -69376.0
# 2006-02-01                                   22849.0
# 1983-06-01                                    -750.0
# 1995-10-01                                     841.0
# 1980-08-01                                     -40.0
# 1985-01-12                                       6.0
# 1982-01-06                                    -775.0
# 1992-09-01                                    -518.0
# 1992-01-01                                     720.0
# 2004-12-01                                   -1385.0
# 2017-10-01                                   27611.0
# 1980-01-03                                    1709.0
# 2016-02-01                                   13486.0
# 2013-01-12                                   40418.0
# 1994-01-12                                    2622.0
# 1991-11-01                                   -1925.0
# 1974-05-01                                     -14.0
# 1995-06-01                                      67.0
# 2008-04-01                                  -39322.0
# 1980-04-01                                     -13.0
# ...                                              ...
# 1997-02-01                                   -3763.0
# 2014-08-01                                   -9542.0
# 2017-06-01                                   24193.0
# 1977-06-01                                     -12.0
# 1974-11-01                                      79.0
# 2003-12-01                                    8656.0
# 2012-08-01                                   17152.0
# 2019-01-03                                  -69376.0
# 1981-01-12                                    -549.0
# 1975-10-01                                     -48.0
# 2004-10-01                                   -1608.0
# 2000-09-01                                    6041.0
# 2014-04-01                                  -25658.0
# 1990-01-01                                    1902.0
# 1995-01-06                                   -1504.0
# 2007-11-01                                   19864.0
# 1999-11-01                                    9440.0
# 1974-09-01                                     -18.0
# 2007-10-01                                   -6308.0
# 2017-05-01                                    8990.0
# 1987-08-01                                     573.0
# 2015-06-01                                   52940.0
# 1970-12-01                                     -61.0
# 1992-10-01                                     -46.0
# 2014-06-01                                   10348.0
# 2018-01-03                                  -17360.0
# 1982-03-01                                    -895.0
# 2009-08-01                                   22247.0
# 2005-02-01                                   -7864.0
# 2013-01-06                                   40418.0
#
#             PortfolioInvestmentAssets
# Date
# 1976-08-01                        0.0
# 1991-01-12                     -159.0
# 1996-04-01                    -1575.0
# 1976-01-06                        0.0
# 2006-10-01                    -4469.0
# 1985-10-01                        0.0
# 1989-11-01                      162.0
# 2016-10-01                    80420.0
# 1992-07-01                      -33.0
# 1994-11-01                       13.0
# 2019-01-09                    34733.0
# 2006-02-01                    -4469.0
# 1983-06-01                        0.0
# 1995-10-01                    -1086.0
# 1980-08-01                        0.0
# 1985-01-12                        0.0
# 1982-01-06                        0.0
# 1992-09-01                      -33.0
# 1992-01-01                     -159.0
# 2004-12-01                    -3156.0
# 2017-10-01                   -14895.0
# 1980-01-03                        0.0
# 2016-02-01                    80420.0
# 2013-01-12                     2871.0
# 1994-01-12                       13.0
# 1991-11-01                     -159.0
# 1974-05-01                        0.0
# 1995-06-01                    -1086.0
# 2008-04-01                   -51058.0
# 1980-04-01                        0.0
# ...                               ...
# 1997-02-01                    -4304.0
# 2014-08-01                    -5526.0
# 2017-06-01                   -14895.0
# 1977-06-01                        0.0
# 1974-11-01                        0.0
# 2003-12-01                     -555.0
# 2012-08-01                   -21433.0
# 2019-01-03                   -17865.0
# 1981-01-12                        0.0
# 1975-10-01                        0.0
# 2004-10-01                    -3156.0
# 2000-09-01                    -3104.0
# 2014-04-01                    -5526.0
# 1990-01-01                      162.0
# 1995-01-06                      -41.0
# 2007-11-01                    -9027.0
# 1999-11-01                    -7625.0
# 1974-09-01                        0.0
# 2007-10-01                    -9027.0
# 2017-05-01                   -14895.0
# 1987-08-01                      -21.0
# 2015-06-01                   -13331.0
# 1970-12-01                        0.0
# 1992-10-01                      -33.0
# 2014-06-01                    -5526.0
# 2018-01-03                   -15948.0
# 1982-03-01                        0.0
# 2009-08-01                    -9649.0
# 2005-02-01                    -3624.0
# 2013-01-06                    -1375.0
#
# [555 rows x 6 columns]

# %% [markdown]
# ## Modelling phase

# %% [markdown]
# ### The following function applies step wise linear regression fit to our model

# %%
scores_list, optimum_no_features = model_fit(X_train,y_train)
print(optimum_no_features)
# Out:
# 0 0.4245171785921674
# 5

# %%
plt_plot(scores_list, 'Score vs Number of varibales selected','Number of variables', 'Score')

# %% [markdown]
# ### Final model which utilizes optimum number of features, which were returned by the above function

# %%
cols_assets = list(X.columns)

selected_features, model, rfe = final_model(optimum_no_features, X_train, y_train,cols_assets)
print(selected_features)
# Out:
# Index(['OtherDomesticFinancialAssets', 'ForeignAssetsTotalOtherInvestment',
#        'ReserveAssets', 'OtherInvestmentAssets', 'PortfolioInvestmentAssets'],
#       dtype='object')

# %% [markdown]
# From our stepwise linear regression we have ended with 5 features only 1 redundant one was removed

# %% [markdown]
# Now model prediction

# %%
y_train_predicted = model.predict(rfe.transform((X_train)))

# %% [markdown]
# ### Model Analysis

# %% [markdown]
# ## Post-Stepwise Regression

# %% [markdown]
# ### Residual analysis

# %%
residuals =y_train.astype(float)- (y_train_predicted)

# %%
sns.residplot(y_train.astype(float),y_train_predicted)

# %%
import statsmodels.formula.api as sm

# %%
formula_features = ' + '.join(list(selected_features))
formula = 'unemployment_rate~'+ formula_features
formula
# Out:
# 'unemployment_rate~OtherDomesticFinancialAssets + ForeignAssetsTotalOtherInvestment + ReserveAssets + OtherInvestmentAssets + PortfolioInvestmentAssets'

# %%
# Add y back to df

X_y_new_train = pd.concat([X_train,pd.DataFrame(y_train)], axis=1)

# %%
X_train_y_target = pd.concat([X_train, pd.DataFrame(y_train)], axis=1)
X_train_y_target
# Out:
#             OtherDomesticFinancialAssets  ForeignAssetsTotalOtherInvestment  \
# Date
# 1976-08-01                           0.0                                2.0
# 1991-01-12                           0.0                                7.0
# 1996-04-01                           0.0                               18.0
# 1976-01-06                           0.0                                0.0
# 2006-10-01                        8839.0                              247.0
# 1985-10-01                           0.0                                5.0
# 1989-11-01                           0.0                                8.0
# 2016-10-01                       46311.0                              521.0
# 1992-07-01                           0.0                                9.0
# 1994-11-01                           0.0                               11.0
# 2019-01-09                        -364.0                              598.0
# 2006-02-01                        8839.0                              247.0
# 1983-06-01                           0.0                                3.0
# 1995-10-01                           0.0                               12.0
# 1980-08-01                           0.0                                3.0
# 1985-01-12                           0.0                                5.0
# 1982-01-06                           0.0                                0.0
# 1992-09-01                           0.0                                9.0
# 1992-01-01                           0.0                                7.0
# 2004-12-01                       16504.0                              164.0
# 2017-10-01                      -11895.0                              530.0
# 1980-01-03                           0.0                                0.0
# 2016-02-01                       46311.0                              521.0
# 2013-01-12                       28897.0                              398.0
# 1994-01-12                           0.0                               11.0
# 1991-11-01                           0.0                                7.0
# 1974-05-01                           0.0                                1.0
# 1995-06-01                           0.0                               12.0
# 2008-04-01                        2921.0                              303.0
# 1980-04-01                           0.0                                3.0
# ...                                  ...                                ...
# 1997-02-01                           0.0                               24.0
# 2014-08-01                       23277.0                              463.0
# 2017-06-01                      -11895.0                              530.0
# 1977-06-01                           0.0                                2.0
# 1974-11-01                           0.0                                1.0
# 2003-12-01                       16134.0                              165.0
# 2012-08-01                       15110.0                              320.0
# 2019-01-03                      -74367.0                              619.0
# 1981-01-12                           0.0                                3.0
# 1975-10-01                           0.0                                1.0
# 2004-10-01                       16504.0                              164.0
# 2000-09-01                           0.0                               60.0
# 2014-04-01                       23277.0                              463.0
# 1990-01-01                           0.0                                8.0
# 1995-01-06                           0.0                                0.0
# 2007-11-01                       12539.0                              271.0
# 1999-11-01                           0.0                               47.0
# 1974-09-01                           0.0                                1.0
# 2007-10-01                       12539.0                              271.0
# 2017-05-01                      -11895.0                              530.0
# 1987-08-01                           0.0                                7.0
# 2015-06-01                        6572.0                              561.0
# 1970-12-01                           0.0                                1.0
# 1992-10-01                           0.0                                9.0
# 2014-06-01                       23277.0                              463.0
# 2018-01-03                      -18450.0                              528.0
# 1982-03-01                           0.0                                3.0
# 2009-08-01                      -14320.0                              251.0
# 2005-02-01                       17533.0                              196.0
# 2013-01-06                      -32247.0                                0.0
#
#             ReserveAssets  OtherInvestmentAssets  \
# Date
# 1976-08-01          0.000                    0.0
# 1991-01-12         88.000                  502.0
# 1996-04-01       -752.000                -3779.0
# 1976-01-06          0.000                    0.0
# 2006-10-01      -7721.000                 3952.0
# 1985-10-01       -185.000                  337.0
# 1989-11-01       -698.000                 -352.0
# 2016-10-01     -54301.000                -9229.0
# 1992-07-01       2345.000                 -917.0
# 1994-11-01      -2323.058                 -573.0
# 2019-01-09     -77164.000                82933.0
# 2006-02-01      -7721.000                 3952.0
# 1983-06-01          0.000                    0.0
# 1995-10-01      -5680.000                   84.0
# 1980-08-01          0.000                    0.0
# 1985-01-12       -185.000                  337.0
# 1982-01-06          0.000                    0.0
# 1992-09-01       2345.000                 -917.0
# 1992-01-01         88.000                  502.0
# 2004-12-01     -13988.000                 3671.0
# 2017-10-01     -14902.000                 -881.0
# 1980-01-03          0.000                    0.0
# 2016-02-01     -54301.000                -9229.0
# 2013-01-12         31.000                  844.0
# 1994-01-12      -2323.058                 -573.0
# 1991-11-01         88.000                  502.0
# 1974-05-01          0.000                    0.0
# 1995-06-01      -5680.000                   84.0
# 2008-04-01      -5830.000                64271.0
# 1980-04-01          0.000                    0.0
# ...                   ...                    ...
# 1997-02-01       2523.000                  304.0
# 2014-08-01      -7623.000               -14448.0
# 2017-06-01     -14902.000                 -881.0
# 1977-06-01          0.000                    0.0
# 1974-11-01          0.000                    0.0
# 2003-12-01       -209.000               -17762.0
# 2012-08-01       -349.000                11967.0
# 2019-01-03      34244.000               -51571.0
# 1981-01-12          0.000                    0.0
# 1975-10-01          0.000                    0.0
# 2004-10-01     -13988.000                 3671.0
# 2000-09-01         18.000                 2982.0
# 2014-04-01      -7623.000               -14448.0
# 1990-01-01       -698.000                 -352.0
# 1995-01-06      -1267.000                 1403.0
# 2007-11-01     -16084.000                30104.0
# 1999-11-01      -3136.000               -10254.0
# 1974-09-01          0.000                    0.0
# 2007-10-01     -16084.000                30104.0
# 2017-05-01     -14902.000                 -881.0
# 1987-08-01        -62.000                 -115.0
# 2015-06-01      -3454.000                47897.0
# 1970-12-01          0.000                    0.0
# 1992-10-01       2345.000                 -917.0
# 2014-06-01      -7623.000               -14448.0
# 2018-01-03      14571.000               -21611.0
# 1982-03-01          0.000                    0.0
# 2009-08-01      -2288.000                  846.0
# 2005-02-01      -6612.000                 9487.0
# 2013-01-06      15149.000                  968.0
#
#             NetForeignAssetsAfterValuationAdjustment  \
# Date
# 1976-08-01                                     -77.0
# 1991-01-12                                    1601.0
# 1996-04-01                                   -4505.0
# 1976-01-06                                    -243.0
# 2006-10-01                                  -17016.0
# 1985-10-01                                    -287.0
# 1989-11-01                                     859.0
# 2016-10-01                                   70897.0
# 1992-07-01                                     849.0
# 1994-11-01                                    1323.0
# 2019-01-09                                  -69376.0
# 2006-02-01                                   22849.0
# 1983-06-01                                    -750.0
# 1995-10-01                                     841.0
# 1980-08-01                                     -40.0
# 1985-01-12                                       6.0
# 1982-01-06                                    -775.0
# 1992-09-01                                    -518.0
# 1992-01-01                                     720.0
# 2004-12-01                                   -1385.0
# 2017-10-01                                   27611.0
# 1980-01-03                                    1709.0
# 2016-02-01                                   13486.0
# 2013-01-12                                   40418.0
# 1994-01-12                                    2622.0
# 1991-11-01                                   -1925.0
# 1974-05-01                                     -14.0
# 1995-06-01                                      67.0
# 2008-04-01                                  -39322.0
# 1980-04-01                                     -13.0
# ...                                              ...
# 1997-02-01                                   -3763.0
# 2014-08-01                                   -9542.0
# 2017-06-01                                   24193.0
# 1977-06-01                                     -12.0
# 1974-11-01                                      79.0
# 2003-12-01                                    8656.0
# 2012-08-01                                   17152.0
# 2019-01-03                                  -69376.0
# 1981-01-12                                    -549.0
# 1975-10-01                                     -48.0
# 2004-10-01                                   -1608.0
# 2000-09-01                                    6041.0
# 2014-04-01                                  -25658.0
# 1990-01-01                                    1902.0
# 1995-01-06                                   -1504.0
# 2007-11-01                                   19864.0
# 1999-11-01                                    9440.0
# 1974-09-01                                     -18.0
# 2007-10-01                                   -6308.0
# 2017-05-01                                    8990.0
# 1987-08-01                                     573.0
# 2015-06-01                                   52940.0
# 1970-12-01                                     -61.0
# 1992-10-01                                     -46.0
# 2014-06-01                                   10348.0
# 2018-01-03                                  -17360.0
# 1982-03-01                                    -895.0
# 2009-08-01                                   22247.0
# 2005-02-01                                   -7864.0
# 2013-01-06                                   40418.0
#
#             PortfolioInvestmentAssets  unemployment_rate
# Date
# 1976-08-01                        0.0            6.13100
# 1991-01-12                     -159.0           13.56330
# 1996-04-01                    -1575.0           20.69500
# 1976-01-06                        0.0            6.27541
# 2006-10-01                    -4469.0           25.89860
# 1985-10-01                        0.0           10.57290
# 1989-11-01                      162.0           11.90780
# 2016-10-01                    80420.0           27.10000
# 1992-07-01                      -33.0           16.61590
# 1994-11-01                       13.0           19.66150
# 2019-01-09                    34733.0           27.10000
# 2006-02-01                    -4469.0           25.56770
# 1983-06-01                        0.0            8.65380
# 1995-10-01                    -1086.0           20.57930
# 1980-08-01                        0.0            7.92073
# 1985-01-12                        0.0            9.73461
# 1982-01-06                        0.0            7.10655
# 1992-09-01                      -33.0           17.07700
# 1992-01-01                     -159.0           15.61220
# 2004-12-01                    -3156.0           25.73440
# 2017-10-01                   -14895.0           27.70000
# 1980-01-03                        0.0            8.22700
# 2016-02-01                    80420.0           24.50000
# 2013-01-12                     2871.0           24.50000
# 1994-01-12                       13.0           19.05590
# 1991-11-01                     -159.0           15.12550
# 1974-05-01                        0.0            7.13417
# 1995-06-01                    -1086.0           20.39790
# 2008-04-01                   -51058.0           23.20000
# 1980-04-01                        0.0            8.05404
# ...                               ...                ...
# 1997-02-01                    -4304.0           21.33030
# 2014-08-01                    -5526.0           25.50000
# 2017-06-01                   -14895.0           27.70000
# 1977-06-01                        0.0            6.97873
# 1974-11-01                        0.0            6.72028
# 2003-12-01                     -555.0           26.11190
# 2012-08-01                   -21433.0           24.80000
# 2019-01-03                   -17865.0           27.10000
# 1981-01-12                        0.0            7.61426
# 1975-10-01                        0.0            6.33601
# 2004-10-01                    -3156.0           25.81340
# 2000-09-01                    -3104.0           26.97630
# 2014-04-01                    -5526.0           25.20000
# 1990-01-01                      162.0           12.16400
# 1995-01-06                      -41.0           19.89710
# 2007-11-01                    -9027.0           24.79630
# 1999-11-01                    -7625.0           25.31160
# 1974-09-01                        0.0            6.72028
# 2007-10-01                    -9027.0           24.79630
# 2017-05-01                   -14895.0           27.70000
# 1987-08-01                      -21.0           10.90200
# 2015-06-01                   -13331.0           25.00000
# 1970-12-01                        0.0            9.05361
# 1992-10-01                      -33.0           17.07700
# 2014-06-01                    -5526.0           25.50000
# 2018-01-03                   -15948.0           26.70000
# 1982-03-01                        0.0            7.18285
# 2009-08-01                    -9649.0           23.20000
# 2005-02-01                    -3624.0           25.73440
# 2013-01-06                    -1375.0           24.50000
#
# [555 rows x 7 columns]

# %%
results = sm.ols(formula=formula,data = X_train_y_target).fit()
import statsmodels.graphics as smgraphics

axss = smgraphics.regressionplots.plot_fit(results, 2)
_ = smgraphics.regressionplots.plot_fit(results, 1)
_ = smgraphics.regressionplots.plot_fit(results, 3)
_ = smgraphics.regressionplots.plot_fit(results, 4)
_ = smgraphics.regressionplots.plot_fit(results, 5)

# %%
Y_ols_pred=results.predict(X_train)

# %%
residuals = y_train - Y_ols_pred

# %%
pred_val = results.fittedvalues.copy()
fig, ax = plt.subplots(figsize=(6,2.5))


_ = ax.scatter(pred_val, residuals)

# %%
fig, ax1 = plt.subplots(figsize=(6,2.5))
_ = ax1.scatter(X_train.iloc[:,2:3], residuals)

# %% [markdown]
# #### Error distribution of residuals

# %%
sns.distplot(residuals)

# %% [markdown]
# #### QQ plots of sample quantiles vs theoretical ones

# %%
import statsmodels.api as sm
_ = sm.qqplot(residuals)

# %% [markdown]
# ### Outlier removal

# %%
test = results.outlier_test()
outliers = ((x[i],y[i]) for i,t in enumerate(test) if t[2] < 0.5)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)

# %%
outliers =(i for i,t in enumerate(test.iloc[:,2]) if t < 0.5)

# %%
# Index of Outliers
outliers_list = list(outliers)

# %%
# Remove outliers
X_train = pd.DataFrame(np.delete(X_train.values, outliers_list,0))
y_train = pd.DataFrame(np.delete(y_train.values, outliers_list,0))
len(X_train)
# Out:
# 555

# %% [markdown]
# ## Final Model

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)

final_model = rlm(formula, data=X_train_y_target,
                      M=sm.robust.norms.HuberT()).fit()

# %%
X_train
# Out:
#             OtherDomesticFinancialAssets  ForeignAssetsTotalOtherInvestment  \
# Date
# 1976-08-01                           0.0                                2.0
# 1991-01-12                           0.0                                7.0
# 1996-04-01                           0.0                               18.0
# 1976-01-06                           0.0                                0.0
# 2006-10-01                        8839.0                              247.0
# 1985-10-01                           0.0                                5.0
# 1989-11-01                           0.0                                8.0
# 2016-10-01                       46311.0                              521.0
# 1992-07-01                           0.0                                9.0
# 1994-11-01                           0.0                               11.0
# 2019-01-09                        -364.0                              598.0
# 2006-02-01                        8839.0                              247.0
# 1983-06-01                           0.0                                3.0
# 1995-10-01                           0.0                               12.0
# 1980-08-01                           0.0                                3.0
# 1985-01-12                           0.0                                5.0
# 1982-01-06                           0.0                                0.0
# 1992-09-01                           0.0                                9.0
# 1992-01-01                           0.0                                7.0
# 2004-12-01                       16504.0                              164.0
# 2017-10-01                      -11895.0                              530.0
# 1980-01-03                           0.0                                0.0
# 2016-02-01                       46311.0                              521.0
# 2013-01-12                       28897.0                              398.0
# 1994-01-12                           0.0                               11.0
# 1991-11-01                           0.0                                7.0
# 1974-05-01                           0.0                                1.0
# 1995-06-01                           0.0                               12.0
# 2008-04-01                        2921.0                              303.0
# 1980-04-01                           0.0                                3.0
# ...                                  ...                                ...
# 1997-02-01                           0.0                               24.0
# 2014-08-01                       23277.0                              463.0
# 2017-06-01                      -11895.0                              530.0
# 1977-06-01                           0.0                                2.0
# 1974-11-01                           0.0                                1.0
# 2003-12-01                       16134.0                              165.0
# 2012-08-01                       15110.0                              320.0
# 2019-01-03                      -74367.0                              619.0
# 1981-01-12                           0.0                                3.0
# 1975-10-01                           0.0                                1.0
# 2004-10-01                       16504.0                              164.0
# 2000-09-01                           0.0                               60.0
# 2014-04-01                       23277.0                              463.0
# 1990-01-01                           0.0                                8.0
# 1995-01-06                           0.0                                0.0
# 2007-11-01                       12539.0                              271.0
# 1999-11-01                           0.0                               47.0
# 1974-09-01                           0.0                                1.0
# 2007-10-01                       12539.0                              271.0
# 2017-05-01                      -11895.0                              530.0
# 1987-08-01                           0.0                                7.0
# 2015-06-01                        6572.0                              561.0
# 1970-12-01                           0.0                                1.0
# 1992-10-01                           0.0                                9.0
# 2014-06-01                       23277.0                              463.0
# 2018-01-03                      -18450.0                              528.0
# 1982-03-01                           0.0                                3.0
# 2009-08-01                      -14320.0                              251.0
# 2005-02-01                       17533.0                              196.0
# 2013-01-06                      -32247.0                                0.0
#
#             ReserveAssets  OtherInvestmentAssets  \
# Date
# 1976-08-01          0.000                    0.0
# 1991-01-12         88.000                  502.0
# 1996-04-01       -752.000                -3779.0
# 1976-01-06          0.000                    0.0
# 2006-10-01      -7721.000                 3952.0
# 1985-10-01       -185.000                  337.0
# 1989-11-01       -698.000                 -352.0
# 2016-10-01     -54301.000                -9229.0
# 1992-07-01       2345.000                 -917.0
# 1994-11-01      -2323.058                 -573.0
# 2019-01-09     -77164.000                82933.0
# 2006-02-01      -7721.000                 3952.0
# 1983-06-01          0.000                    0.0
# 1995-10-01      -5680.000                   84.0
# 1980-08-01          0.000                    0.0
# 1985-01-12       -185.000                  337.0
# 1982-01-06          0.000                    0.0
# 1992-09-01       2345.000                 -917.0
# 1992-01-01         88.000                  502.0
# 2004-12-01     -13988.000                 3671.0
# 2017-10-01     -14902.000                 -881.0
# 1980-01-03          0.000                    0.0
# 2016-02-01     -54301.000                -9229.0
# 2013-01-12         31.000                  844.0
# 1994-01-12      -2323.058                 -573.0
# 1991-11-01         88.000                  502.0
# 1974-05-01          0.000                    0.0
# 1995-06-01      -5680.000                   84.0
# 2008-04-01      -5830.000                64271.0
# 1980-04-01          0.000                    0.0
# ...                   ...                    ...
# 1997-02-01       2523.000                  304.0
# 2014-08-01      -7623.000               -14448.0
# 2017-06-01     -14902.000                 -881.0
# 1977-06-01          0.000                    0.0
# 1974-11-01          0.000                    0.0
# 2003-12-01       -209.000               -17762.0
# 2012-08-01       -349.000                11967.0
# 2019-01-03      34244.000               -51571.0
# 1981-01-12          0.000                    0.0
# 1975-10-01          0.000                    0.0
# 2004-10-01     -13988.000                 3671.0
# 2000-09-01         18.000                 2982.0
# 2014-04-01      -7623.000               -14448.0
# 1990-01-01       -698.000                 -352.0
# 1995-01-06      -1267.000                 1403.0
# 2007-11-01     -16084.000                30104.0
# 1999-11-01      -3136.000               -10254.0
# 1974-09-01          0.000                    0.0
# 2007-10-01     -16084.000                30104.0
# 2017-05-01     -14902.000                 -881.0
# 1987-08-01        -62.000                 -115.0
# 2015-06-01      -3454.000                47897.0
# 1970-12-01          0.000                    0.0
# 1992-10-01       2345.000                 -917.0
# 2014-06-01      -7623.000               -14448.0
# 2018-01-03      14571.000               -21611.0
# 1982-03-01          0.000                    0.0
# 2009-08-01      -2288.000                  846.0
# 2005-02-01      -6612.000                 9487.0
# 2013-01-06      15149.000                  968.0
#
#             NetForeignAssetsAfterValuationAdjustment  \
# Date
# 1976-08-01                                     -77.0
# 1991-01-12                                    1601.0
# 1996-04-01                                   -4505.0
# 1976-01-06                                    -243.0
# 2006-10-01                                  -17016.0
# 1985-10-01                                    -287.0
# 1989-11-01                                     859.0
# 2016-10-01                                   70897.0
# 1992-07-01                                     849.0
# 1994-11-01                                    1323.0
# 2019-01-09                                  -69376.0
# 2006-02-01                                   22849.0
# 1983-06-01                                    -750.0
# 1995-10-01                                     841.0
# 1980-08-01                                     -40.0
# 1985-01-12                                       6.0
# 1982-01-06                                    -775.0
# 1992-09-01                                    -518.0
# 1992-01-01                                     720.0
# 2004-12-01                                   -1385.0
# 2017-10-01                                   27611.0
# 1980-01-03                                    1709.0
# 2016-02-01                                   13486.0
# 2013-01-12                                   40418.0
# 1994-01-12                                    2622.0
# 1991-11-01                                   -1925.0
# 1974-05-01                                     -14.0
# 1995-06-01                                      67.0
# 2008-04-01                                  -39322.0
# 1980-04-01                                     -13.0
# ...                                              ...
# 1997-02-01                                   -3763.0
# 2014-08-01                                   -9542.0
# 2017-06-01                                   24193.0
# 1977-06-01                                     -12.0
# 1974-11-01                                      79.0
# 2003-12-01                                    8656.0
# 2012-08-01                                   17152.0
# 2019-01-03                                  -69376.0
# 1981-01-12                                    -549.0
# 1975-10-01                                     -48.0
# 2004-10-01                                   -1608.0
# 2000-09-01                                    6041.0
# 2014-04-01                                  -25658.0
# 1990-01-01                                    1902.0
# 1995-01-06                                   -1504.0
# 2007-11-01                                   19864.0
# 1999-11-01                                    9440.0
# 1974-09-01                                     -18.0
# 2007-10-01                                   -6308.0
# 2017-05-01                                    8990.0
# 1987-08-01                                     573.0
# 2015-06-01                                   52940.0
# 1970-12-01                                     -61.0
# 1992-10-01                                     -46.0
# 2014-06-01                                   10348.0
# 2018-01-03                                  -17360.0
# 1982-03-01                                    -895.0
# 2009-08-01                                   22247.0
# 2005-02-01                                   -7864.0
# 2013-01-06                                   40418.0
#
#             PortfolioInvestmentAssets
# Date
# 1976-08-01                        0.0
# 1991-01-12                     -159.0
# 1996-04-01                    -1575.0
# 1976-01-06                        0.0
# 2006-10-01                    -4469.0
# 1985-10-01                        0.0
# 1989-11-01                      162.0
# 2016-10-01                    80420.0
# 1992-07-01                      -33.0
# 1994-11-01                       13.0
# 2019-01-09                    34733.0
# 2006-02-01                    -4469.0
# 1983-06-01                        0.0
# 1995-10-01                    -1086.0
# 1980-08-01                        0.0
# 1985-01-12                        0.0
# 1982-01-06                        0.0
# 1992-09-01                      -33.0
# 1992-01-01                     -159.0
# 2004-12-01                    -3156.0
# 2017-10-01                   -14895.0
# 1980-01-03                        0.0
# 2016-02-01                    80420.0
# 2013-01-12                     2871.0
# 1994-01-12                       13.0
# 1991-11-01                     -159.0
# 1974-05-01                        0.0
# 1995-06-01                    -1086.0
# 2008-04-01                   -51058.0
# 1980-04-01                        0.0
# ...                               ...
# 1997-02-01                    -4304.0
# 2014-08-01                    -5526.0
# 2017-06-01                   -14895.0
# 1977-06-01                        0.0
# 1974-11-01                        0.0
# 2003-12-01                     -555.0
# 2012-08-01                   -21433.0
# 2019-01-03                   -17865.0
# 1981-01-12                        0.0
# 1975-10-01                        0.0
# 2004-10-01                    -3156.0
# 2000-09-01                    -3104.0
# 2014-04-01                    -5526.0
# 1990-01-01                      162.0
# 1995-01-06                      -41.0
# 2007-11-01                    -9027.0
# 1999-11-01                    -7625.0
# 1974-09-01                        0.0
# 2007-10-01                    -9027.0
# 2017-05-01                   -14895.0
# 1987-08-01                      -21.0
# 2015-06-01                   -13331.0
# 1970-12-01                        0.0
# 1992-10-01                      -33.0
# 2014-06-01                    -5526.0
# 2018-01-03                   -15948.0
# 1982-03-01                        0.0
# 2009-08-01                    -9649.0
# 2005-02-01                    -3624.0
# 2013-01-06                    -1375.0
#
# [555 rows x 6 columns]

# %%
final_model_predicted = final_model.predict(X_test)

# %%
params = np.array(final_model.params)

# %%
metrics.r2_score(y_test, final_model_predicted)
# Out:
# 0.5018729659508269

# %%
print_p_values(X_test, y_test, final_model_predicted, params)
# Out:
# Coefficients       0.0001
# Standard Errors    0.0000
# t values           2.3140
# P-Values           0.0220
# Name: 1, dtype: float64

# %% [markdown]
# The test for $H_{0}$ by using the following statistic:
# $$
# F_{0} = \frac{MS_R}{MS_E}
# $$
# where $MS_R$ is the regression mean square and $MS_E$ is the error mean square.
# <br>
# The null hypothesis, $H_{0}$, is rejected if the calculated statistic. $f_{0}, is usch that$
# $$
# F_{0} > f
# $$
# I will now test my hypothesist using $F$

# %%
def fstat_test(final_model):
    A = np.identity(len(final_model.params))
    A = A[1:,:]
    fvalue = final_model.f_test(A).fvalue
    print("The fvalue is " + str(fvalue[0][0]))

# %%
fstat_test(final_model)
# Out:
# The fvalue is 110.53373551242422

# %%
degresOfFreedom = len(X_train) - (len(X_train.columns)+1)
scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd=degresOfFreedom)
# Out:
# 3.0121687848368994

# %% [markdown]
# As shown above, $F_{0} = 110.5337$ and $f = 3.0121$.
# <br>
# <br>
# Since $F_0$ > $f$, $H_{0}$ is rejected and it is concluded that at least one $\beta_{i}$ cofficient is significant. In other words, it is concluded that a regression model exists between the exploratory and response variables

# %% [markdown]
# # Unemployement rate in SA: Investigating the relationship between governments profits/losses on investments and unemployment rate in South Africa

# %% [markdown]
# ## Do investment returns affect the employment rate?

# %% [markdown]
# Features about the government's investments were collected from the remaining features with no multi collinearity

# %%
def get_inv_features(a, b):
    df_new = list()
    x_col = x_values_ffill.columns.tolist()
    for i in x_col:
        if a in i:
            df_new.append(x_values_ffill[i])
            print(i)
        if b in i:
            df_new.append(x_values_ffill[i])
            print(i)
    return df_new

# %%
df_inv = get_inv_features('evalua', 'nvest') 
DF_INV = pd.DataFrame(data = df_inv)
# Out:
# Foreign liabilities: Total portfolio investment
# Foreign liabilities: Portfolio investment: Equity securities
# Foreign liabilities: Portfolio investment: Debt securities
# Net Investment Position
# Foreign liabilities: Total other investment
# Foreign assets: Total other investment
# Foreign assets: Portfolio investment: Debt securities
# The net borrowing requirement of national government equals the net result of the cash-flow deficit/surplus and the cost of revaluation of foreign loans at redemption.
# Foreign assets: Total direct investment
# Other investment, liabilities
# Foreign assets: Total portfolio investment
# Foreign assets: Portfolio investment: Equity securities
# Other investment, assets
# Cost/profit of revaluation of foreign loans
# Portfolio investment, liabilities
# Foreign liabilities: Total direct investment
# Direct investment abroad
# Portfolio investment, assets
# Direct investment in reporting economy

# %%
X_INV= DF_INV.transpose()
df2 = df2.rename(columns={'unemployment rate':'unemployment_rate'})
y_inv = df2['unemployment_rate']
X_INV.columns.tolist()
# Out:
# ['Foreign liabilities: Total portfolio investment ',
#  'Foreign liabilities: Portfolio investment: Equity securities',
#  'Foreign liabilities: Portfolio investment: Debt securities',
#  'Net Investment Position',
#  'Foreign liabilities: Total other investment',
#  'Foreign assets: Total other investment',
#  'Foreign assets: Portfolio investment: Debt securities',
#  'The net borrowing requirement of national government equals the net result of the cash-flow deficit/surplus and the cost of revaluation of foreign loans at redemption. ',
#  'Foreign assets: Total direct investment',
#  'Other investment, liabilities',
#  'Foreign assets: Total portfolio investment',
#  'Foreign assets: Portfolio investment: Equity securities',
#  'Other investment, assets',
#  'Cost/profit of revaluation of foreign loans ',
#  'Portfolio investment, liabilities',
#  'Foreign liabilities: Total direct investment',
#  'Direct investment abroad',
#  'Portfolio investment, assets',
#  'Direct investment in reporting economy']

# %%
def wordopt(text):
    text = text.lower() 
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W"," ",text) 
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
correlated_features = set()
correlation_matrix = X_INV.corr()

for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)
# Out:
# 9

# %%
X_INV.drop(labels=correlated_features, axis=1, inplace=True)
X_INV.shape
# Out:
# (794, 10)

# %%
for col in X_INV.columns:
    new_w = wordopt(col)
    X_INV.rename(columns= {col: new_w.replace(' ', '')}, inplace = True)
X_train_inv, X_test_inv, y_train_inv, y_test_inv = train_test_split(X_INV,y_inv, test_size = 0.3, random_state = 0)
X_train_inv
# Out:
#             foreignliabilitiestotalportfolioinvestment  netinvestmentposition  \
# Date
# 1976-08-01                                         3.0                  -14.0
# 1991-01-12                                        28.0                  -37.0
# 1996-04-01                                       112.0                 -132.0
# 1976-01-06                                         0.0                    0.0
# 2006-10-01                                       716.0                 -459.0
# 1985-10-01                                        12.0                  -56.0
# 1989-11-01                                        19.0                  -37.0
# 2016-10-01                                      2801.0                  306.0
# 1992-07-01                                        38.0                  -46.0
# 1994-11-01                                        67.0                  -87.0
# 2019-01-09                                      3313.0                  695.0
# 2006-02-01                                       716.0                 -459.0
# 1983-06-01                                         7.0                  -31.0
# 1995-10-01                                        86.0                 -106.0
# 1980-08-01                                         5.0                  -14.0
# 1985-01-12                                        12.0                  -56.0
# 1982-01-06                                         0.0                    0.0
# 1992-09-01                                        38.0                  -46.0
# 1992-01-01                                        28.0                  -37.0
# 2004-12-01                                       354.0                 -209.0
# 2017-10-01                                      3598.0                  425.0
# 1980-01-03                                         0.0                    0.0
# 2016-02-01                                      2801.0                  306.0
# 2013-01-12                                      2089.0                 -154.0
# 1994-01-12                                        67.0                  -87.0
# 1991-11-01                                        28.0                  -37.0
# 1974-05-01                                         3.0                   -9.0
# 1995-06-01                                        86.0                 -106.0
# 2008-04-01                                       797.0                 -165.0
# 1980-04-01                                         5.0                  -14.0
# ...                                                ...                    ...
# 1997-02-01                                       137.0                 -117.0
# 2014-08-01                                      2575.0                 -302.0
# 2017-06-01                                      3598.0                  425.0
# 1977-06-01                                         3.0                  -16.0
# 1974-11-01                                         3.0                   -9.0
# 2003-12-01                                       307.0                 -134.0
# 2012-08-01                                      1729.0                 -472.0
# 2019-01-03                                      3508.0                 1055.0
# 1981-01-12                                         5.0                  -20.0
# 1975-10-01                                         3.0                  -12.0
# 2004-10-01                                       354.0                 -209.0
# 2000-09-01                                       277.0                  -81.0
# 2014-04-01                                      2575.0                 -302.0
# 1990-01-01                                        19.0                  -37.0
# 1995-01-06                                         0.0                    0.0
# 2007-11-01                                       907.0                 -640.0
# 1999-11-01                                       260.0                 -177.0
# 1974-09-01                                         3.0                   -9.0
# 2007-10-01                                       907.0                 -640.0
# 2017-05-01                                      3598.0                  425.0
# 1987-08-01                                        15.0                  -35.0
# 2015-06-01                                      2581.0                  637.0
# 1970-12-01                                         2.0                   -6.0
# 1992-10-01                                        38.0                  -46.0
# 2014-06-01                                      2575.0                 -302.0
# 2018-01-03                                      3491.0                  343.0
# 1982-03-01                                         6.0                  -26.0
# 2009-08-01                                       934.0                 -423.0
# 2005-02-01                                       524.0                 -346.0
# 2013-01-06                                         0.0                    0.0
#
#             thenetborrowingrequirementofnationalgovernmentequalsthenetresultofthecashflowdeficitsurplusandthecostofrevaluationofforeignloansatredemption  \
# Date
# 1976-08-01                                              -73.0
# 1991-01-12                                             1686.0
# 1996-04-01                                            -3464.0
# 1976-01-06                                              -26.0
# 2006-10-01                                            -4445.0
# 1985-10-01                                             -537.0
# 1989-11-01                                              613.0
# 2016-10-01                                           -29268.0
# 1992-07-01                                             -634.0
# 1994-11-01                                            -3897.0
# 2019-01-09                                           -35090.0
# 2006-02-01                                            -7891.0
# 1983-06-01                                             -299.0
# 1995-10-01                                             1748.0
# 1980-08-01                                             1112.0
# 1985-01-12                                                5.0
# 1982-01-06                                               85.0
# 1992-09-01                                              470.0
# 1992-01-01                                              238.0
# 2004-12-01                                            10892.0
# 2017-10-01                                           -29052.0
# 1980-01-03                                              -18.0
# 2016-02-01                                             7306.0
# 2013-01-12                                           -24614.0
# 1994-01-12                                             1642.0
# 1991-11-01                                            -2648.0
# 1974-05-01                                              -59.0
# 1995-06-01                                            -1467.0
# 2008-04-01                                           -15305.0
# 1980-04-01                                             -568.0
# ...                                                       ...
# 1997-02-01                                           -11050.0
# 2014-08-01                                             -448.0
# 2017-06-01                                            26357.0
# 1977-06-01                                             -204.0
# 1974-11-01                                             -128.0
# 2003-12-01                                             8445.0
# 2012-08-01                                            -6118.0
# 2019-01-03                                           -35090.0
# 1981-01-12                                                5.0
# 1975-10-01                                             -233.0
# 2004-10-01                                            -1076.0
# 2000-09-01                                              536.0
# 2014-04-01                                           -42282.0
# 1990-01-01                                             2928.0
# 1995-01-06                                             2525.0
# 2007-11-01                                            -7348.0
# 1999-11-01                                            -2992.0
# 1974-09-01                                              -55.0
# 2007-10-01                                            -5367.0
# 2017-05-01                                           -16091.0
# 1987-08-01                                              487.0
# 2015-06-01                                            29891.0
# 1970-12-01                                               11.0
# 1992-10-01                                            -2355.0
# 2014-06-01                                            26422.0
# 2018-01-03                                           -90387.0
# 1982-03-01                                             -253.0
# 2009-08-01                                            -7514.0
# 2005-02-01                                           -16738.0
# 2013-01-06                                           -24614.0
#
#             otherinvestmentliabilities  otherinvestmentassets  \
# Date
# 1976-08-01                         0.0                    0.0
# 1991-01-12                       -72.0                  502.0
# 1996-04-01                     10757.0                -3779.0
# 1976-01-06                         0.0                    0.0
# 2006-10-01                      2371.0                 3952.0
# 1985-10-01                      -376.0                  337.0
# 1989-11-01                       -41.0                 -352.0
# 2016-10-01                      8490.0                -9229.0
# 1992-07-01                      -122.0                 -917.0
# 1994-11-01                     -3163.0                 -573.0
# 2019-01-09                       857.0                82933.0
# 2006-02-01                      2371.0                 3952.0
# 1983-06-01                         0.0                    0.0
# 1995-10-01                      3817.0                   84.0
# 1980-08-01                         0.0                    0.0
# 1985-01-12                      -376.0                  337.0
# 1982-01-06                         0.0                    0.0
# 1992-09-01                      -122.0                 -917.0
# 1992-01-01                       -72.0                  502.0
# 2004-12-01                      3625.0                 3671.0
# 2017-10-01                     -4303.0                 -881.0
# 1980-01-03                         0.0                    0.0
# 2016-02-01                      8490.0                -9229.0
# 2013-01-12                     31034.0                  844.0
# 1994-01-12                     -3163.0                 -573.0
# 1991-11-01                       -72.0                  502.0
# 1974-05-01                         0.0                    0.0
# 1995-06-01                      3817.0                   84.0
# 2008-04-01                     -3390.0                64271.0
# 1980-04-01                         0.0                    0.0
# ...                                ...                    ...
# 1997-02-01                     -1251.0                  304.0
# 2014-08-01                     55227.0               -14448.0
# 2017-06-01                     -4303.0                 -881.0
# 1977-06-01                         0.0                    0.0
# 1974-11-01                         0.0                    0.0
# 2003-12-01                      9263.0               -17762.0
# 2012-08-01                     38331.0                11967.0
# 2019-01-03                     35780.0               -51571.0
# 1981-01-12                         0.0                    0.0
# 1975-10-01                         0.0                    0.0
# 2004-10-01                      3625.0                 3671.0
# 2000-09-01                     -6198.0                 2982.0
# 2014-04-01                     55227.0               -14448.0
# 1990-01-01                       -41.0                 -352.0
# 1995-01-06                      5910.0                 1403.0
# 2007-11-01                      5423.0                30104.0
# 1999-11-01                     -3117.0               -10254.0
# 1974-09-01                         0.0                    0.0
# 2007-10-01                      5423.0                30104.0
# 2017-05-01                     -4303.0                 -881.0
# 1987-08-01                        48.0                 -115.0
# 2015-06-01                     44184.0                47897.0
# 1970-12-01                         0.0                    0.0
# 1992-10-01                      -122.0                 -917.0
# 2014-06-01                     55227.0               -14448.0
# 2018-01-03                      1060.0               -21611.0
# 1982-03-01                         0.0                    0.0
# 2009-08-01                       689.0                  846.0
# 2005-02-01                       683.0                 9487.0
# 2013-01-06                       218.0                  968.0
#
#             costprofitofrevaluationofforeignloans  \
# Date
# 1976-08-01                                    0.0
# 1991-01-12                                    0.0
# 1996-04-01                                    0.0
# 1976-01-06                                    0.0
# 2006-10-01                                 -540.0
# 1985-10-01                                    0.0
# 1989-11-01                                    0.0
# 2016-10-01                                -4647.0
# 1992-07-01                                    0.0
# 1994-11-01                                    0.0
# 2019-01-09                                    0.0
# 2006-02-01                                 -542.0
# 1983-06-01                                    0.0
# 1995-10-01                                    0.0
# 1980-08-01                                    0.0
# 1985-01-12                                    0.0
# 1982-01-06                                    0.0
# 1992-09-01                                    0.0
# 1992-01-01                                    0.0
# 2004-12-01                                  -10.0
# 2017-10-01                                 -435.0
# 1980-01-03                                    0.0
# 2016-02-01                                    0.0
# 2013-01-12                                 -139.0
# 1994-01-12                                    0.0
# 1991-11-01                                    0.0
# 1974-05-01                                    0.0
# 1995-06-01                                    0.0
# 2008-04-01                                -1828.0
# 1980-04-01                                    0.0
# ...                                           ...
# 1997-02-01                                    0.0
# 2014-08-01                                  -24.0
# 2017-06-01                                -1201.0
# 1977-06-01                                    0.0
# 1974-11-01                                    0.0
# 2003-12-01                                  -17.0
# 2012-08-01                                  -11.0
# 2019-01-03                                    0.0
# 1981-01-12                                    0.0
# 1975-10-01                                    0.0
# 2004-10-01                                 -481.0
# 2000-09-01                                    0.0
# 2014-04-01                                 -493.0
# 1990-01-01                                    0.0
# 1995-01-06                                    0.0
# 2007-11-01                                  -39.0
# 1999-11-01                                    0.0
# 1974-09-01                                    0.0
# 2007-10-01                                  -59.0
# 2017-05-01                                   -4.0
# 1987-08-01                                    0.0
# 2015-06-01                                    0.0
# 1970-12-01                                    0.0
# 1992-10-01                                    0.0
# 2014-06-01                                -4005.0
# 2018-01-03                                    0.0
# 1982-03-01                                  -69.0
# 2009-08-01                                  -16.0
# 2005-02-01                                    0.0
# 2013-01-06                                 -139.0
#
#             portfolioinvestmentliabilities  directinvestmentabroad  \
# Date
# 1976-08-01                             0.0                     0.0
# 1991-01-12                           887.0                  -641.0
# 1996-04-01                          -516.0                 -1278.0
# 1976-01-06                             0.0                     0.0
# 2006-10-01                         31519.0                  5980.0
# 1985-10-01                          -107.0                   -11.0
# 1989-11-01                          -235.0                  -185.0
# 2016-10-01                          1910.0                -28527.0
# 1992-07-01                           750.0                 -1559.0
# 1994-11-01                          4094.0                  -555.0
# 2019-01-09                         40192.0                -21592.0
# 2006-02-01                         31519.0                  5980.0
# 1983-06-01                             0.0                     0.0
# 1995-10-01                          3277.0                 -1634.0
# 1980-08-01                             0.0                     0.0
# 1985-01-12                          -107.0                   -11.0
# 1982-01-06                             0.0                     0.0
# 1992-09-01                           750.0                 -1559.0
# 1992-01-01                           887.0                  -641.0
# 2004-12-01                         22611.0                  1207.0
# 2017-10-01                         94275.0                  3156.0
# 1980-01-03                             0.0                     0.0
# 2016-02-01                          1910.0                -28527.0
# 2013-01-12                          7879.0                -17591.0
# 1994-01-12                          4094.0                  -555.0
# 1991-11-01                           887.0                  -641.0
# 1974-05-01                             0.0                     0.0
# 1995-06-01                          3277.0                 -1634.0
# 2008-04-01                        -60617.0                 42254.0
# 1980-04-01                             0.0                     0.0
# ...                                    ...                     ...
# 1997-02-01                          2636.0                 -4495.0
# 2014-08-01                          2578.0                -14066.0
# 2017-06-01                         94275.0                  3156.0
# 1977-06-01                             0.0                     0.0
# 1974-11-01                             0.0                     0.0
# 2003-12-01                         -6107.0                 -1017.0
# 2012-08-01                         58779.0                -15472.0
# 2019-01-03                         29165.0                -15285.0
# 1981-01-12                             0.0                     0.0
# 1975-10-01                             0.0                     0.0
# 2004-10-01                         22611.0                  1207.0
# 2000-09-01                         -1833.0                 -1282.0
# 2014-04-01                          2578.0                -14066.0
# 1990-01-01                          -235.0                  -185.0
# 1995-01-06                          1986.0                 -2956.0
# 2007-11-01                          2630.0                 -5572.0
# 1999-11-01                         18690.0                   395.0
# 1974-09-01                             0.0                     0.0
# 2007-10-01                          2630.0                 -5572.0
# 2017-05-01                         94275.0                  3156.0
# 1987-08-01                         -1086.0                  -212.0
# 2015-06-01                          4221.0                -38530.0
# 1970-12-01                             0.0                     0.0
# 1992-10-01                           750.0                 -1559.0
# 2014-06-01                          2578.0                -14066.0
# 2018-01-03                         89416.0                -20792.0
# 1982-03-01                             0.0                     0.0
# 2009-08-01                         41241.0                 -5374.0
# 2005-02-01                         -3652.0                 -4806.0
# 2013-01-06                         17957.0                -10146.0
#
#             portfolioinvestmentassets  directinvestmentinreportingeconomy
# Date
# 1976-08-01                        0.0                                 0.0
# 1991-01-12                     -159.0                              -508.0
# 1996-04-01                    -1575.0                              1296.0
# 1976-01-06                        0.0                                 0.0
# 2006-10-01                    -4469.0                            -10447.0
# 1985-10-01                        0.0                              -248.0
# 1989-11-01                      162.0                              -296.0
# 2016-10-01                    80420.0                              2039.0
# 1992-07-01                      -33.0                               -12.0
# 1994-11-01                       13.0                               179.0
# 2019-01-09                    34733.0                             17024.0
# 2006-02-01                    -4469.0                            -10447.0
# 1983-06-01                        0.0                                 0.0
# 1995-10-01                    -1086.0                              1191.0
# 1980-08-01                        0.0                                 0.0
# 1985-01-12                        0.0                              -248.0
# 1982-01-06                        0.0                                 0.0
# 1992-09-01                      -33.0                               -12.0
# 1992-01-01                     -159.0                              -508.0
# 2004-12-01                    -3156.0                             -3877.0
# 2017-10-01                   -14895.0                            -13817.0
# 1980-01-03                        0.0                                 0.0
# 2016-02-01                    80420.0                              2039.0
# 2013-01-12                     2871.0                              4502.0
# 1994-01-12                       13.0                               179.0
# 1991-11-01                     -159.0                              -508.0
# 1974-05-01                        0.0                                 0.0
# 1995-06-01                    -1086.0                              1191.0
# 2008-04-01                   -51058.0                              2469.0
# 1980-04-01                        0.0                                 0.0
# ...                               ...                                 ...
# 1997-02-01                    -4304.0                              6659.0
# 2014-08-01                    -5526.0                             19290.0
# 2017-06-01                   -14895.0                            -13817.0
# 1977-06-01                        0.0                                 0.0
# 1974-11-01                        0.0                                 0.0
# 2003-12-01                     -555.0                              3021.0
# 2012-08-01                   -21433.0                              -981.0
# 2019-01-03                   -17865.0                             11733.0
# 1981-01-12                        0.0                                 0.0
# 1975-10-01                        0.0                                 0.0
# 2004-10-01                    -3156.0                             -3877.0
# 2000-09-01                    -3104.0                              -861.0
# 2014-04-01                    -5526.0                             19290.0
# 1990-01-01                      162.0                              -296.0
# 1995-01-06                      -41.0                               458.0
# 2007-11-01                    -9027.0                             14721.0
# 1999-11-01                    -7625.0                              2569.0
# 1974-09-01                        0.0                                 0.0
# 2007-10-01                    -9027.0                             14721.0
# 2017-05-01                   -14895.0                            -13817.0
# 1987-08-01                      -21.0                              -243.0
# 2015-06-01                   -13331.0                             14341.0
# 1970-12-01                        0.0                                 0.0
# 1992-10-01                      -33.0                               -12.0
# 2014-06-01                    -5526.0                             19290.0
# 2018-01-03                   -15948.0                              9262.0
# 1982-03-01                        0.0                                 0.0
# 2009-08-01                    -9649.0                              7933.0
# 2005-02-01                    -3624.0                              6057.0
# 2013-01-06                    -1375.0                             17501.0
#
# [555 rows x 10 columns]

# %%
def invest_model_fit(X_fit,y_fit):    
    feature_list=np.arange(1, len(X_train_inv.columns))            
    high_score=0
    optimum_no_features=0           
    score_list =[]
    for n in range(len(feature_list)):
        model = LinearRegression()
        rfe = RFE(model,feature_list[n])
        X_train_rfe = rfe.fit_transform(X_train_inv,y_train_inv)
        model.fit(X_train_rfe,y_train_inv)

        score = r2_score(y_fit, model.predict(X_train_rfe))
        score_list.append(score)

        if(score>high_score):
            high_score = score  
            optimum_no_features = feature_list[n]
    return score_list, optimum_no_features

# %%
scores_list_inv, optimum_no_features_inv = invest_model_fit(X_train_inv,y_train_inv)
print("Number of features selected:",optimum_no_features_inv)
# Out:
# Number of features selected: 9

# %%
plt_plot(scores_list, 'Score vs Number of varibales selected','Number of variables', 'Score')

# %% [markdown]
# The r squared scores seem to be increasing for the selected investment features. The scores remain less that 0.4 probably because of the small number of features used

# %%
def final_inv_model(n, X_final_inv, y_final_inv):
    cols = list(X_INV.columns)
    model = LinearRegression()
    #Initializing RFE model
    rfe = RFE(model, n)             
    #Transforming data using RFE
    x_fitted = rfe.fit_transform(X_final_inv,y_final_inv)  
    #Fitting the data to model
    model.fit(x_fitted,y_final_inv)              
    temp = pd.Series(rfe.support_,index = cols)
    selected_features = temp[temp==True].index
    return selected_features, model, rfe

# %%
print(optimum_no_features_inv)
selected_inv_features, inv_model, inv_rfe = final_inv_model(optimum_no_features_inv, X_train_inv, y_train_inv)
selected_inv_features.tolist()
# Out:
# 9
# ['foreignliabilitiestotalportfolioinvestment',
#  'netinvestmentposition',
#  'otherinvestmentliabilities',
#  'otherinvestmentassets',
#  'costprofitofrevaluationofforeignloans',
#  'portfolioinvestmentliabilities',
#  'directinvestmentabroad',
#  'portfolioinvestmentassets',
#  'directinvestmentinreportingeconomy']

# %%
y_train_inv_predicted = inv_model.predict(inv_rfe.transform((X_train_inv)))

# %% [markdown]
# ## Residual Analysis

# %%
inv_residuals =y_train_inv.astype(float)- (y_train_inv_predicted)
sns.residplot(y_train_inv.astype(float),y_train_inv_predicted)

# %% [markdown]
# The residual points are not evenly dustributed vertically. The predictions get worse as the unemployment rate increases. The residuals show heteroscedasticity pattern which happens when regression assumes that the residuals come data with constant variance. This resuslts in low confidence in the model.

# %%
import statsmodels.api as sm
_ = sm.qqplot(inv_residuals)

# %%
sns.distplot(inv_residuals)

# %% [markdown]
# The residuals are not normally distributed

# %%
formula_inv_features = ' + '.join(list(selected_inv_features))
formula_inv = 'unemployment_rate~'+ formula_inv_features

# %%
X_y_new_inv_train = pd.concat([X_train_inv,pd.DataFrame(y_train_inv)], axis=1)

# %%
X_train_y_target_INV = pd.concat([X_train_inv, pd.DataFrame(y_train_inv)], axis=1)

# %%
import statsmodels.formula.api as sm
results = sm.ols(formula=formula_inv,data = X_train_y_target_INV).fit()
import statsmodels.graphics as smgraphics

axss = smgraphics.regressionplots.plot_fit(results, 1)
_ = smgraphics.regressionplots.plot_fit(results, 2)

# %% [markdown]
# # Final Investment Model

# %%
import statsmodels.api as sm
final_inv_model = rlm(formula_inv, data=X_train_y_target_INV,
                      M=sm.robust.norms.HuberT()).fit()

# %%
final_inv_model_predicted = final_inv_model.predict(X_test_inv)
inv_params = np.array(final_inv_model.params)
print(inv_params.shape)
print(X_test_inv.shape)
metrics.r2_score(y_test_inv, final_inv_model_predicted)
# Out:
# (10,)
# (239, 10)
# 0.5079337606066539

# %%
def print_p_values_inv(x_test, y_test, predicted, params):
    """
    Calculates the p value, based on https://stackoverflow.com/a/42677750/9260653
    """
    newX = np.append(np.ones((len(x_test),1)), x_test, axis=1)
    MSE = (sum((y_test.values-predicted)**2))/(len(newX)-len(newX[0]))

    var_b = MSE*(np.linalg.pinv(np.dot(newX.T,newX)).diagonal())
    sd_b = np.sqrt(var_b)[:-1]
    print(params.shape)
    ts_b = params/ sd_b
    
    p_values =[2*(1-stats.t.cdf(np.abs(i),(len(newX)-1))) for i in ts_b]

    sd_b = np.round(sd_b,3)
    ts_b = np.round(ts_b,3)
    p_values = np.round(p_values,4)
    params = np.round(params,4)

    myDF3 = pd.DataFrame()
    myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["P-Values"] = [params,sd_b,ts_b,p_values]
    print(myDF3.iloc[1])

# %%
# inv_params.shape
print_p_values_inv(X_test_inv, y_test_inv, final_inv_model_predicted, inv_params)
# Out:
# (10,)
# Coefficients       0.0053
# Standard Errors    0.0010
# t values           7.3900
# P-Values           0.0000
# Name: 1, dtype: float64

# %%
def fstat_test(final_model):
    A = np.identity(len(final_model.params))
    A = A[1:,:]
    fvalue = final_model.f_test(A).fvalue
    print("The f value is " + str(fvalue[0][0]))

# %%
fstat_test(final_inv_model)
degresOfFreedom = len(X_train_inv) - (len(X_train_inv.columns)+1)
scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd=degresOfFreedom)
# Out:
# The f value is 51.55909528861816
# 3.012290086049356

# %% [markdown]
# With a p-value 0f less than 0.01 and f value = 51.55 greater than f = 3.012 showing high significance, we can reject the hypothesis that investment has an effect on unemployment rate.

# %% [markdown]
# # Unemployement rate in SA: Exploring the multi-variables of cash flow in South Africa that affects the rate of unemployement

# %% [markdown]
# ## 3. How does the government cash flow affect unemployment rate?

# %%
column_names = list()
for i in x_values_ffill:
    if 'cash' in i:
        column_names.append(i)
column_names #7
# Out:
# ['Total cash-flow revenue',
#  'Cash received from the issuance of other debt instruments less cash payments made to redeem other debt instruments, including non-marketable bills and bonds, and debt of the former TBVC-countries, self-governing territories and the Republic of Namibia that were assumed by the national government. ',
#  'Consolidated general government: Net change in the stock of cash_x',
#  'Cash received from the issuance of domestic government bonds less cash payments made to redeem domestic government bonds.',
#  'The net borrowing requirement of national government equals the net result of the cash-flow deficit/surplus and the cost of revaluation of foreign loans at redemption. ',
#  'Cash received from the issuance of foreign bonds and loans less cash payments made to redeem foreign bonds and loans.',
#  'Cash received from the issuance of Treasury bills less cash payments made to redeem Treasury bills.',
#  'The difference between cash-flow revenue and cash-flow expenditure._x',
#  'The difference between cash-flow revenue and cash-flow expenditure._y',
#  'Consolidated general government: Net change in the stock of cash_y',
#  'Consolidated general government: Net cash-flow from financing activities',
#  'Consolidated general government: Net acquisition of financial assets other than cash',
#  'Net cash-flow from operating activities ']

# %% [markdown]
# ### Function to select varables about cash flow
# This helper function helps with selecting featues about the speific topic that needs to be researched

# %%
def get_features(s):
    df_new = list()

    for i in column_names:
        if s in i:
            df_new.append(x_values_ffill[i])
            print(i)
    return df_new

# %%
df_cash = get_features('cash') 
DF = pd.DataFrame(data = df_cash)
# Out:
# Total cash-flow revenue
# Cash received from the issuance of other debt instruments less cash payments made to redeem other debt instruments, including non-marketable bills and bonds, and debt of the former TBVC-countries, self-governing territories and the Republic of Namibia that were assumed by the national government.
# Consolidated general government: Net change in the stock of cash_x
# Cash received from the issuance of domestic government bonds less cash payments made to redeem domestic government bonds.
# The net borrowing requirement of national government equals the net result of the cash-flow deficit/surplus and the cost of revaluation of foreign loans at redemption.
# Cash received from the issuance of foreign bonds and loans less cash payments made to redeem foreign bonds and loans.
# Cash received from the issuance of Treasury bills less cash payments made to redeem Treasury bills.
# The difference between cash-flow revenue and cash-flow expenditure._x
# The difference between cash-flow revenue and cash-flow expenditure._y
# Consolidated general government: Net change in the stock of cash_y
# Consolidated general government: Net cash-flow from financing activities
# Consolidated general government: Net acquisition of financial assets other than cash
# Net cash-flow from operating activities

# %%
X_cash= DF.transpose()

correlated_features_cash = set()
correlation_matrix_cash = X_cash.corr()

for i in range(len(correlation_matrix_cash.columns)):
    for j in range(i):
        if abs(correlation_matrix_cash.iloc[i, j]) > 0.5:
            colname = correlation_matrix_cash.columns[i]
            correlated_features_cash.add(colname)
len(correlated_features_cash)
# Out:
# 5

# %%
for col in X_cash.columns:
    new_w = wordopt(col)
    X_cash.rename(columns= {col: new_w.replace(' ', '')}, inplace = True)

Y_cash = df2['unemployment_rate']

# %% [markdown]
# ### Data splitting
#
# The predefined ratio used for data splitting is 70/30 reason being that I want to improve the accuracy of the evaluation of the model.

# %%
X_train_cash, X_test_cash, y_train_cash, y_test_cash = train_test_split(X_cash,Y_cash, test_size = 0.3, random_state = 0)

# %% [markdown]
# ## Modeling - Stepwise regression

# %%
scores_list_cash, optimum_no_features_cash = model_fit(X_train_cash,y_train_cash)
# Out:
# 0 0.006632037826124537
# 10 0.5543111898943884

# %%
plt_plot(scores_list_cash, 'Score vs Number of varibales selected','Number of variables', 'Score')

# %%
# fit final model using optimum number of features from prev function

def final_model_cash(optimum_no_features, X_train, y_train):
    cols = list(X_cash.columns)
    model = LinearRegression()
    #Initializing RFE model
    rfe = RFE(model, optimum_no_features)             
    #Transforming data using RFE
    x_fitted = rfe.fit_transform(X_train,y_train)  
    #Fitting the data to model
    model.fit(x_fitted,y_train)              
    temp = pd.Series(rfe.support_,index = cols)
    selected_features = temp[temp==True].index
    return selected_features, model, rfe

# %%
selected_features_cash, model_cash, rfe_cash = final_model_cash(optimum_no_features_cash, X_train_cash, y_train_cash)

# %%
y_train_predicted_cash = model_cash.predict(rfe_cash.transform((X_train_cash)))

# %% [markdown]
# ## Model Fit Analaysis

# %% [markdown]
# # Post-Stepwise Regression

# %% [markdown]
# ## Residual Analysis

# %%
residuals = y_train_cash-y_train_predicted_cash

# %%
sns.residplot(y_train_cash,y_train_predicted_cash)

# %% [markdown]
# ### We can apply normal probability plot to assess how the data (error) depart from normality visually:

# %%
formula_features_cash = ' + '.join(list(selected_features_cash))
formula_cash = 'unemployment_rate~'+ formula_features_cash

# %%
# Add y back to df
X_y_new_train_cash = pd.concat([X_train_cash,pd.DataFrame(y_train_cash)], axis=1)

# %%
X_train_y_target_cash = pd.concat([X_train_cash, pd.DataFrame(y_train_cash)], axis=1)
# X_train_y_target

# %%
import statsmodels.graphics as smgraphics
import statsmodels.formula.api as sm
results_cash = sm.ols(formula=formula_cash,data = X_train_y_target_cash).fit()
axss_cash = smgraphics.regressionplots.plot_fit(results_cash,3)
_ = smgraphics.regressionplots.plot_fit(results_cash,2)

# %%
Y_ols_pred_cash=results_cash.predict(X_train_cash)

# %%
residuals_cash = y_train_cash - Y_ols_pred_cash

# %%
fig, ax1 = plt.subplots(figsize=(6,2.5))
_ = ax1.scatter(X_train_cash.iloc[:,5:6], residuals_cash)

# %%
sns.distplot(residuals)

# %%
import statsmodels.api as sm
_ = sm.qqplot(residuals_cash)

# %% [markdown]
# ### Outlier Detection and removal
# Here outliers are detected and deleted and used the remaining observations for fitting the model.

# %%
test_cash = results.outlier_test()
outliers_cash = ((x[i],y[i]) for i,t in enumerate(test) if t[2] < 0.5)

# %%
X_train_cash, X_test_cash, y_train_cash, y_test_cash = train_test_split(X_cash,Y_cash, test_size = 0.3, random_state = 0)

# %%
outliers_cash =(i for i,t in enumerate(test.iloc[:,2]) if t < 0.5)

# %%
# Index of Outliers
outliers_list_cash = list(outliers)

# %%
# Remove outliers
X_train_cash = pd.DataFrame(np.delete(X_train_cash.values, outliers_list_cash,0))
y_train_cash = pd.DataFrame(np.delete(y_train_cash.values, outliers_list_cash,0))

# %% [markdown]
# ## Final Model

# %%
X_train_cash, X_test_cash, y_train_cash, y_test_cash = train_test_split(X_cash,Y_cash, test_size = 0.3, random_state = 0)

final_model_cash = rlm(formula_cash, data=X_train_y_target_cash,
                      M=sm.robust.norms.HuberT()).fit()

# %%
final_model_predicted_cash = final_model_cash.predict(X_test_cash)

# %%
params_cash = np.array(final_model_cash.params)

# %%
metrics.r2_score(y_test, final_model_predicted)
# Out:
# 0.5018729659508269

# %%
print_p_values(X_test_cash, y_test_cash, final_model_predicted_cash, params_cash)
# Out:
# Coefficients      -0.0099
# Standard Errors    0.0070
# t values          -1.3420
# P-Values           0.1810
# Name: 1, dtype: float64

# %% [markdown]
# he test for $H_{0}$ byusing the following statistic:
# $$
# F_{0} = \frac{MS_R}{MS_E}
# $$
# where $MS_R$ is the regression mean square and $MS_E$ is the error mean square.
# <br>
# The null hypothesis, $H_{0}$, is rejected if the calculated statistic. $f_{0}, is usch that$
# $$
# F_{0} > f
# $$
# I will now test my hypothesist using $F$

# %%
def fstat_test(final_model):
    A = np.identity(len(final_model.params))
    A = A[1:,:]
    fvalue = final_model.f_test(A).fvalue
    print("The fvalue is " + str(fvalue[0][0]))

# %%
fstat_test(final_model)
# Out:
# The fvalue is 110.53373551242422

# %%
degresOfFreedom = len(X_train) - (len(X_train.columns)+1)
scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd=degresOfFreedom)
# Out:
# 3.0121687848368994

# %% [markdown]
# As shown above, $F_{0} = 110.5337$ and $f = 3.004779$.
# <br>
# <br>
# Since $F_0$ > $f$, $H_{0}$ is rejected and it is concluded that at least one $\beta_{i}$ cofficient is significant. In other words, it is concluded that a regression model exists between the exploratory and response variables

# %% [markdown]
# # Unemployement rate in SA: Exploring the relationship between multiple variables that may influence the unemployment rate of South Africa

# %% [markdown]
# ## 4. How does the government debt affect unemployment rate?

# %%
predictors = x_values_ffill
DF_Y = y_values_ffill

# %%
def get_features(s):
    df_new = pd.DataFrame()

    for i in predictors:        
        if s in i:
            df_new[i] = predictors[i]

    return df_new

# %%
df_new_1 = get_features('debt')
df_new_2 = get_features('outstanding')
df = pd.concat([df_new_1 , df_new_2 , DF_Y], axis=1)

# %% [markdown]
# # Exploratory Plots

# %%
sns.heatmap(df.corr())

# %% [markdown]
# # Colinearity

# %%
def correlation(dataset, threshold):
    col_corr = set() # Set of all the names of deleted columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j] >= threshold) and (corr_matrix.columns[j] not in col_corr):
                colname = corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)
                if colname in dataset.columns:
                    del dataset[colname] # deleting the column from the dataset

# %%
# removing all the corrated values with a correlation value over 0.7
DF_X = df.copy()
correlation(DF_X,0.7)

# %%
values = list(DF_X.columns)
keys = list('ABCDEFGH')

zip1 = zip(keys, values)



dictionary = dict(zip1)


print(dictionary)
# Out:
# {'A': 'Foreign debt of S.A.: Total foreign debt ', 'B': 'Cash received from the issuance of other debt instruments less cash payments made to redeem other debt instruments, including non-marketable bills and bonds, and debt of the former TBVC-countries, self-governing territories and the Republic of Namibia that were assumed by the national government. ', 'C': 'Total other debt ', 'D': 'Total foreign non-marketable debt ', 'E': 'Total outstanding domestic marketable loan levies', 'F': 'Total outstanding domestic marketable bonds: Not exceeding 1 year (incl SA housing trust loans i.e marketable SP05 bonds)', 'G': 'Total outstanding foreign marketable bonds by unexpired maturity: Not exceeding 1 year', 'H': 'Total outstanding domestic non-marketable loan levies'}

# %%
DF_X.columns = keys
DF_Y.columns = ['unemployment_rate']

# %% [markdown]
# # Modelling
# ## Stepwise regression

# %%
X_train_debt, X_test_debt, y_train_debt, y_test_debt = train_test_split(DF_X,DF_Y, test_size = 0.3, random_state = 0)

# %%
def final_model_debt(optimum_no_features, X_train, y_train):
    cols = list(DF_X.columns)
    model = LinearRegression()
    #Initializing RFE model
    rfe = RFE(model, optimum_no_features)             
    #Transforming data using RFE
    x_fitted = rfe.fit_transform(X_train,y_train)  
    #Fitting the data to model
    model.fit(x_fitted,y_train)              
    temp = pd.Series(rfe.support_,index = cols)
    selected_features = temp[temp==True].index
    return selected_features, model, rfe

# %%
# Train model using X_train, y_train
X_train_debt
scores_list_debt, optimum_no_features_debt = model_fit(X_train_debt,y_train_debt)
# Out:
# 0 0.48593002562915577

# %%
plt_plot(scores_list_debt, 'Score vs Number of varibales selected','Number of variables', 'Score')

# %%
selected_features_debt, model_debt, rfe_debt = final_model_debt(optimum_no_features_debt, X_train_debt, y_train_debt)

# %%
y_train_predicted_debt = model_debt.predict(rfe_debt.transform((X_train_debt)))

# %% [markdown]
# ## Model Fit Analaysis

# %% [markdown]
# # Post-Stepwise Regression

# %% [markdown]
# ## Residual Analysis

# %%
residuals_debt = y_train_debt-y_train_predicted_debt
residuals_debt.head()
# Out:
#             unemployment_rate
# Date
# 1976-08-01          -5.629983
# 1991-01-12          -1.471032
# 1996-04-01          -0.674359
# 1976-01-06          -5.829179
# 2006-10-01          -1.693501

# %%
ax = sns.residplot(y_train_debt,y_train_predicted_debt)

# %%
### We can apply normal probability plot to assess how the data (error) depart from normality visually:

# %%
import statsmodels.formula.api as sm

# %%
formula_features_debt = ' + '.join(list(selected_features_debt))
formula_debt = 'unemployment_rate~'+ formula_features_debt

# %%
# Add y back to df

X_y_new_train_debt = pd.concat([X_train_debt, y_train_debt], axis=1)

# %%
X_train_y_target_debt = pd.concat([X_train_debt, y_train_debt], axis=1)

# %%
results_debt = sm.ols(formula=formula_debt,data = X_train_y_target_debt).fit()
import statsmodels.graphics as smgraphics

axss = smgraphics.regressionplots.plot_fit(results_debt, 1)
_ = smgraphics.regressionplots.plot_fit(results_debt,5)

# %%
Y_ols_pred_debt=results_debt.predict(X_train_debt)
Y_ols_pred_debt = pd.DataFrame(Y_ols_pred_debt)
Y_ols_pred_debt.columns = ['unemployment_rate']

# %%
pred_val_debt = results_debt.fittedvalues.copy()
fig, ax = plt.subplots(figsize=(6,2.5))

residuals.shape
_ = ax.scatter(pred_val_debt, residuals_debt)

# %%
fig, ax1 = plt.subplots(figsize=(6,2.5))
_ = ax1.scatter(X_train_debt.iloc[:,5:6], residuals_debt)

# %%
# Plot shows that the residuals are normally distributed
sns.distplot(residuals)

# %%
import statsmodels.api as sm
_ = sm.qqplot(residuals)

# %% [markdown]
# ### Outlier Detection and removal

# %%
test_debt = results_debt.outlier_test()
outliers_debt = ((x[i],y[i]) for i,t in enumerate(test_debt) if t[2] < 0.5)

# %%
X_train_debt, X_test_debt, y_train_debt, y_test_debt = train_test_split(DF_X,DF_Y, test_size = 0.3, random_state = 0)

# %%
outliers_debt =(i for i,t in enumerate(test.iloc[:,2]) if t < 0.5)

# %%
# Index of Outliers
outliers_list_debt = list(outliers_debt)

# %%
# Remove outliers
X_train_debt = pd.DataFrame(np.delete(X_train_debt.values, outliers_list_debt,0))
y_train_debt = pd.DataFrame(np.delete(y_train_debt.values, outliers_list_debt,0))
len(X_train_debt)
# Out:
# 555

# %% [markdown]
# ## Final Model

# %%
X_train_debt, X_test_debt, y_train_debt, y_test_debt = train_test_split(DF_X,DF_Y, test_size = 0.3, random_state = 0)

final_model_debt = rlm(formula_debt, data=X_train_y_target_debt,
                      M=sm.robust.norms.HuberT()).fit()

# %%
X_train_debt.head()
# Out:
#                   A     B       C        D      E        F       G      H
# Date
# 1976-08-01      0.0  50.0     0.0    792.0    0.0      0.0    14.0  605.0
# 1991-01-12      0.0  -5.0     0.0    565.0  705.0   3864.0   648.0    3.0
# 1996-04-01      0.0 -37.0  8683.0   4274.0    0.0  13826.0  2351.0    3.0
# 1976-01-06      0.0   5.0     0.0    609.0    0.0      0.0    17.0  528.0
# 2006-10-01  60372.0 -43.0   319.0  23290.0    0.0  34998.0  3793.0    3.0

# %%
final_model_predicted_debt = final_model_debt.predict(X_test_debt)

# %%
params_debt = np.array(final_model_debt.params)

# %%
metrics.r2_score(y_test_debt, final_model_predicted_debt)
# Out:
# 0.775175305171641

# %%
def print_p_values_debt(x_test, y_test, predicted, params):
    """
    Calculates the p value, based on https://stackoverflow.com/a/42677750/9260653
    """
    newX = np.append(np.ones((len(x_test),1)), x_test, axis=1)
    MSE = mean_squared_error(y_test.values,predicted.values)

    var_b = MSE*(np.linalg.pinv(np.dot(newX.T,newX)).diagonal())
    sd_b = np.sqrt(var_b)[:-1]
    ts_b = params/ sd_b

    p_values =[2*(1-stats.t.cdf(np.abs(i),(len(newX)-1))) for i in ts_b]

    sd_b = np.round(sd_b,3)
    ts_b = np.round(ts_b,3)
    p_values = np.round(p_values,3)
    params = np.round(params,4)

    myDF3 = pd.DataFrame()
    myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["P-Values"] = [params,sd_b,ts_b,p_values]
    print(myDF3.iloc[1])

# %%
print(params_debt.shape)
print(final_model_predicted_debt.shape)
print_p_values_debt(X_test_debt, y_test_debt, final_model_predicted_debt, params_debt)
# Out:
# (8,)
# (239,)
# Coefficients       -0.0001
# Standard Errors     0.0000
# t values          -14.5650
# P-Values            0.0000
# Name: 1, dtype: float64

# %% [markdown]
#  The test for $H_{0}$ byusing the following statistic:
# $$
# F_{0} = \frac{MS_R}{MS_E}
# $$
# where $MS_R$ is the regression mean square and $MS_E$ is the error mean square.
# <br>
# The null hypothesis, $H_{0}$, is rejected if the calculated statistic. $f_{0}, is usch that$
# $$
# F_{0} > f
# $$
# I will now test my hypothesist using $F$

# %%
def fstat_test(final_model):
    A = np.identity(len(final_model.params))
    A = A[1:,:]
    fvalue = final_model.f_test(A).fvalue
    print("The fvalue is " + str(fvalue[0][0]))

# %%
fstat_test(final_model_debt)
# Out:
# The fvalue is 304.57224028606146

# %%
degresOfFreedom = len(X_train) - (len(X_train_debt.columns)+1)
scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd=degresOfFreedom)
# Out:
# 3.0122292124661048

# %% [markdown]
# As shown above, $F_{0} = 304.572$ and $f = 3.01217$.
# <br>
# <br>
# Since $F_0$ > $f$, $H_{0}$ is rejected and it is concluded that at least one $\beta_{i}$ cofficient is significant. In other words, it is concluded that a regression model exists between the exploratory and response variables

# %% [markdown]
# # Conlcusion
